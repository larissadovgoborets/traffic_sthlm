# %%
import requests
import pandas as pd
import pprint

# Define the API endpoint
api_url1 = "https://deviations.integration.sl.se/v1/messages?future=<true/false>&site=<siteId1,siteId2>&line=<lineId1,lineId2>&transport_mode=<mode1,mode2>"

api_url = "https://deviations.integration.sl.se/v1/messages"

# Make a GET request to fetch the data
response = requests.get(api_url)

# Check if the request was successful
if response.status_code == 200:
    # Load the data into a pandas DataFrame
    data = response.json()
    print("Data fetched successfully!")
else:
    print(f"Failed to fetch data. Status code: {response.status_code}")

# Display the first few rows of the DataFrame

pprint.pprint(data)
# Out:
# Data fetched successfully!
# [{'created': '2024-10-30T10:39:58.453+01:00',
#   'deviation_case_id': 4549227,
#   'message_variants': [{'details': 'Hållplats Kvarnängsvägen är flyttad 175 '
#                                    'meter fram runt hörnet för buss linje 711 '
#                                    'mot Visättra sportcenter, 712 mot '
#                                    'Björnkulla, 713 mot Björnkulla och 794 mot '
#                                    'Visättra från och med 2024-10-30 pga '
#                                    'vägarbete.\n'
#                                    'Detta planeras pågå till och med '
#                                    '2024-12-31.',
#                         'header': 'Hållplats Kvarnängsvägen flyttad',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 711, 712, 713, 794'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-10-30T10:39:58.447+01:00',
#               'upto': '2024-12-31T23:30:00.000+01:00'},
#   'scope': {'lines': [{'designation': '711',
#                        'id': 711,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '712',
#                        'id': 712,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '713',
#                        'id': 713,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '794',
#                        'id': 794,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 70735,
#                             'name': 'Kvarnängsvägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-08-27T07:04:08.75+02:00',
#   'deviation_case_id': 3808782,
#   'message_variants': [{'details': 'Buss linje 507 stannar inte vid Karolinska '
#                                    'sjukhuset norra och Solna kyrka från och '
#                                    'med 2024-08-27 på grund av vägarbete.\n'
#                                    '\n'
#                                    'Detta beräknas pågå till och med '
#                                    '2025-03-28.\n'
#                                    '\n'
#                                    'Resinärer mot Solna hänvisas till linje '
#                                    '506 \n'
#                                    '\n'
#                                    'Resinärer mot Stockholm hänvisas till '
#                                    'linjer 3,72 eller 77',
#                         'header': 'Indragen hållplats',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 507'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-08-27T20:00:00.000+02:00',
#               'upto': '2025-03-28T04:30:00.000+01:00'},
#   'scope': {'lines': [{'designation': '507',
#                        'id': 507,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 50444,
#                             'name': 'Solna kyrka',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 50800,
#                             'name': 'Karolinska sjukhuset norra',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-10-28T11:31:37.293+01:00',
#   'deviation_case_id': 4522779,
#   'message_variants': [{'details': '697 Danderyds sjukhus\n'
#                                    'Hållplats  Lillhersbyvägen flyttas ca 80 '
#                                    'meter framåt mot Danderyds sjukhus p.g.a. '
#                                    'vägarbete.',
#                         'header': 'Flyttad hållplats',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 697'}],
#   'priority': {'importance_level': 5, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-10-29T07:00:00.000+01:00',
#               'upto': '2024-11-09T03:00:00.000+01:00'},
#   'scope': {'lines': [{'designation': '697',
#                        'id': 697,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 52332,
#                             'name': 'Lillhersbyvägen',
#                             'stop_points': [{'id': 52335,
#                                              'name': 'Lillhersbyvägen'}],
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'categories': [{'group': 'FACILITY', 'type': 'LIFT'}],
#   'created': '2024-10-21T12:08:55.177+02:00',
#   'deviation_case_id': 4441912,
#   'message_variants': [{'details': 'Hissen vid Hässelby strand är avstängd på '
#                                    'grund av underhållsarbete. Resenärer i '
#                                    'behov av hiss kan ta buss 119 till och '
#                                    'från Hässelby gård eller '
#                                    'tillgänglighetsgarantin.\n'
#                                    '\n'
#                                    'Hissen beräknas vara i drift igen den 16 '
#                                    'december.\n',
#                         'header': 'Avstängd hiss vid Hässelby strand',
#                         'language': 'sv',
#                         'scope_alias': 'Tunnelbanans gröna linje 17, 18, 19'}],
#   'priority': {'importance_level': 2, 'influence_level': 3, 'urgency_level': 1},
#   'publish': {'from': '2024-10-28T06:00:00.000+01:00',
#               'upto': '2024-12-16T18:00:00.000+01:00'},
#   'scope': {'lines': [{'designation': '19',
#                        'group_of_lines': 'tunnelbanans gröna linje',
#                        'id': 19,
#                        'name': 'Gröna linjen',
#                        'transport_authority': 1,
#                        'transport_mode': 'METRO'},
#                       {'designation': '17',
#                        'group_of_lines': 'tunnelbanans gröna linje',
#                        'id': 17,
#                        'name': 'Gröna linjen',
#                        'transport_authority': 1,
#                        'transport_mode': 'METRO'},
#                       {'designation': '18',
#                        'group_of_lines': 'tunnelbanans gröna linje',
#                        'id': 18,
#                        'name': 'Gröna linjen',
#                        'transport_authority': 1,
#                        'transport_mode': 'METRO'}],
#             'stop_areas': [{'id': 1331,
#                             'name': 'Hässelby strand',
#                             'transport_authority': 1,
#                             'type': 'METROSTN'}]},
#   'version': 3},
#  {'created': '2024-09-25T11:11:03.267+02:00',
#   'deviation_case_id': 4143437,
#   'message_variants': [{'details': 'Hållplatserna Campus Roslagen, '
#                                    'Gustavslund, Rösa trafikplats, Sätuna, '
#                                    'Västra Libby, Östra Libby  indragna.\n'
#                                    '\n'
#                                    'Tillagda hållplatser blir Husby vägskäl '
#                                    '(mot Finsta), Vallbyberg och Finsta '
#                                    'station.',
#                         'header': 'Indragen hållplats',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 653'}],
#   'priority': {'importance_level': 5, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-09-30T03:30:00.000+02:00',
#               'upto': '2025-09-26T05:50:00.000+02:00'},
#   'scope': {'lines': [{'designation': '653',
#                        'id': 653,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 62569,
#                             'name': 'Östra Libby',
#                             'stop_points': [{'id': 62570,
#                                              'name': 'Östra Libby'}],
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 62567,
#                             'name': 'Västra Libby',
#                             'stop_points': [{'id': 62567,
#                                              'name': 'Västra Libby'},
#                                             {'id': 62568,
#                                              'name': 'Västra Libby'}],
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 63054,
#                             'name': 'Rösa trafikplats',
#                             'stop_points': [{'id': 63054,
#                                              'name': 'Rösa trafikplats'},
#                                             {'id': 63055,
#                                              'name': 'Rösa trafikplats'}],
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 62573,
#                             'name': 'Gustavslund',
#                             'stop_points': [{'id': 62573,
#                                              'name': 'Gustavslund'},
#                                             {'id': 62574,
#                                              'name': 'Gustavslund'}],
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 64146,
#                             'name': 'Campus Roslagen',
#                             'stop_points': [{'id': 64902,
#                                              'name': 'Campus Roslagen'},
#                                             {'id': 64146,
#                                              'name': 'Campus Roslagen'}],
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 64727,
#                             'name': 'Sätuna',
#                             'stop_points': [{'id': 64728, 'name': 'Sätuna'},
#                                             {'id': 64727, 'name': 'Sätuna'}],
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-10-25T06:01:33.983+02:00',
#   'deviation_case_id': 2511163,
#   'message_variants': [{'details': 'Hållplats Skånska gården är flyttad 50 '
#                                    'meter bakåt i färdriktningen för buss '
#                                    'linje 421 mot Orminge centrum och 441 mot '
#                                    'Slussen från och med 2024-04-15 pga '
#                                    'vägarbete.\n'
#                                    'Detta planeras pågå till och med '
#                                    '2025-04-13.',
#                         'header': 'Hållplats Skånska gården flyttad',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 421, 441'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-10-25T06:01:33.977+02:00',
#               'upto': '2025-04-13T23:30:00.000+02:00'},
#   'scope': {'lines': [{'designation': '441',
#                        'id': 441,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '421',
#                        'id': 421,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 40485,
#                             'name': 'Skånska gården',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 3},
#  {'created': '2024-08-20T15:37:34.92+02:00',
#   'deviation_case_id': 3729665,
#   'message_variants': [{'details': 'Hållplats Münchenbryggeriet är flyttad '
#                                    'till ett tillfälligt läge på Torkel '
#                                    'Knutssonsgatan i båda färdriktningarna för '
#                                    'buss linje 405 från och med 2024-08-23 pga '
#                                    'vägarbete.\n'
#                                    'Detta planeras pågå till och med '
#                                    '2024-11-23.',
#                         'header': 'Hållplats Münchenbryggeriet flyttad',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 405'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-08-23T06:00:00.000+02:00',
#               'upto': '2024-11-23T23:59:00.000+01:00'},
#   'scope': {'lines': [{'designation': '405',
#                        'id': 405,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 10494,
#                             'name': 'Münchenbryggeriet',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-10-17T07:32:54.827+02:00',
#   'deviation_case_id': 4397238,
#   'message_variants': [{'details': 'Hållplats Enhagsslingan flyttad 160 meter '
#                                    'framåt.\n'
#                                    '\n'
#                                    'Hållplatsen tillgänglighetsanpassas. \n'
#                                    '\n'
#                                    'Gäller cirka 3 veckor.',
#                         'header': 'Flyttad hållplats',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 604'}],
#   'priority': {'importance_level': 5, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-10-17T07:32:54.823+02:00',
#               'upto': '2024-11-11T03:00:00.000+01:00'},
#   'scope': {'lines': [{'designation': '604',
#                        'id': 604,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 60425,
#                             'name': 'Enhagsslingan',
#                             'stop_points': [{'id': 60425,
#                                              'name': 'Enhagsslingan'}],
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-10-02T02:13:36.797+02:00',
#   'deviation_case_id': 4217120,
#   'message_variants': [{'details': 'För  969 Färsna  är hållplatserna   '
#                                    'Drottninggatan, Norrtälje sjukhus  '
#                                    'indragna tillsvidare',
#                         'header': 'Indragen hållplats',
#                         'language': 'sv',
#                         'scope_alias': 'Närtrafiken 969'}],
#   'priority': {'importance_level': 5, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-10-02T02:13:36.790+02:00',
#               'upto': '2025-09-26T05:50:00.000+02:00'},
#   'scope': {'lines': [{'designation': '969',
#                        'group_of_lines': 'Närtrafiken',
#                        'id': 969,
#                        'name': 'Närtrafiken Norrtälje',
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 65037,
#                             'name': 'Norrtälje sjukhus',
#                             'stop_points': [{'id': 65037,
#                                              'name': 'Norrtälje sjukhus'}],
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 65035,
#                             'name': 'Drottninggatan',
#                             'stop_points': [{'id': 65035,
#                                              'name': 'Drottninggatan'}],
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-10-09T15:16:41.947+02:00',
#   'deviation_case_id': 4305855,
#   'message_variants': [{'details': 'Buss linje 854 stannar inte vid hållplats '
#                                    'Kullstaplan på Grönviksvägen.Bussar kör '
#                                    'omlagd körväg under byggtid och trafikerar '
#                                    'hållplatsen Kullstaplan  på Nynäsvägen i '
#                                    'båda riktningar sedan 2024-10-16 på grund '
#                                    'av vägarbete.\n'
#                                    'Detta beräknas pågå till cirka 2024-12-21.',
#                         'header': 'Indragen hållplats',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 854'}],
#   'priority': {'importance_level': 7, 'influence_level': 3, 'urgency_level': 1},
#   'publish': {'from': '2024-10-16T04:00:00.000+02:00',
#               'upto': '2024-12-21T23:30:00.000+01:00'},
#   'scope': {'lines': [{'designation': '854',
#                        'id': 854,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 75515,
#                             'name': 'Kullstaplan',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-07-25T17:05:30.603+02:00',
#   'deviation_case_id': 3540919,
#   'message_variants': [{'details': 'Vid Hökarängen kan sprängningsarbeten för '
#                                    'tunnelbanans utbyggnad utföras på vardagar '
#                                    'kl. 09:50-15:20, till och med 31 december. '
#                                    'Buller och vibrationer kan märkas både '
#                                    'inom och utanför stationen. De exakta '
#                                    'klockslag dessa sprängningar kan ske är '
#                                    'kl. 09:57, 10:27, 10:57, 11:57, 12:57, '
#                                    '13:27, 13:57 samt kl. 15:15.',
#                         'header': 'Sprängningsarbeten vid Hökarängen',
#                         'language': 'sv',
#                         'scope_alias': 'Tunnelbanans gröna linje 18'}],
#   'priority': {'importance_level': 2, 'influence_level': 3, 'urgency_level': 1},
#   'publish': {'from': '2024-08-01T07:45:00.000+02:00',
#               'upto': '2024-12-31T15:30:00.000+01:00'},
#   'scope': {'lines': [{'designation': '18',
#                        'group_of_lines': 'tunnelbanans gröna linje',
#                        'id': 18,
#                        'name': 'Gröna linjen',
#                        'transport_authority': 1,
#                        'transport_mode': 'METRO'}],
#             'stop_areas': [{'id': 1861,
#                             'name': 'Hökarängen',
#                             'transport_authority': 1,
#                             'type': 'METROSTN'}]},
#   'version': 1},
#  {'created': '2024-10-30T10:15:21.08+01:00',
#   'deviation_case_id': 3167038,
#   'message_variants': [{'details': 'Hållplats Tullingebergsvägen är flyttad 60 '
#                                    'meter bakåt i färdriktningen för buss '
#                                    'linje 723 mot Tullinge station från och '
#                                    'med 2024-06-10 pga vägarbete.\n'
#                                    'Detta planeras pågå till och med '
#                                    '2024-11-15.',
#                         'header': 'Hållplats Tullingebergsvägen flyttad',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 723'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-10-30T10:15:21.073+01:00',
#               'upto': '2024-11-15T16:00:00.000+01:00'},
#   'scope': {'lines': [{'designation': '723',
#                        'id': 723,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 70208,
#                             'name': 'Tullingebergsvägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 3},
#  {'created': '2024-09-05T15:35:12.893+02:00',
#   'deviation_case_id': 3615684,
#   'message_variants': [{'details': 'Vid Stadshagen är entrén från '
#                                    'Mariedalsvägen/Hornsberg stängd på grund '
#                                    'av underhållsarbete. \n'
#                                    '\n'
#                                    'Hänvisning till uppgången mot Sankt '
#                                    'Göransgatan/Kellgrensgatan.\n'
#                                    '\n'
#                                    'Arbetet beräknas pågå t.o.m. hösten 2024.',
#                         'header': 'Entré vid Stadshagen stängd',
#                         'language': 'sv',
#                         'scope_alias': 'Tunnelbanans blå linje 10, 11'}],
#   'priority': {'importance_level': 2, 'influence_level': 3, 'urgency_level': 1},
#   'publish': {'from': '2024-09-05T15:35:12.890+02:00',
#               'upto': '2024-12-31T18:00:00.000+01:00'},
#   'scope': {'lines': [{'designation': '10',
#                        'group_of_lines': 'tunnelbanans blå linje',
#                        'id': 10,
#                        'name': 'Blå linjen',
#                        'transport_authority': 1,
#                        'transport_mode': 'METRO'},
#                       {'designation': '11',
#                        'group_of_lines': 'tunnelbanans blå linje',
#                        'id': 11,
#                        'name': 'Blå linjen',
#                        'transport_authority': 1,
#                        'transport_mode': 'METRO'}],
#             'stop_areas': [{'id': 3161,
#                             'name': 'Stadshagen',
#                             'transport_authority': 1,
#                             'type': 'METROSTN'}]},
#   'version': 4},
#  {'categories': [{'group': 'FACILITY', 'type': 'LIFT'}],
#   'created': '2024-10-29T22:23:57.04+01:00',
#   'deviation_case_id': 4542437,
#   'message_variants': [{'details': 'Hissen vid Skarpnäck från biljetthallen '
#                                    'till mellanplanet, är avstängd på grund av '
#                                    'tekniskt fel. \n'
#                                    '\n'
#                                    'Vi saknar prognos på när hissen åter kan '
#                                    'tas i bruk.\n'
#                                    '\n',
#                         'header': 'Avstängd hiss vid Skarpnäck',
#                         'language': 'sv',
#                         'scope_alias': 'Tunnelbanans gröna linje 17'}],
#   'priority': {'importance_level': 2, 'influence_level': 3, 'urgency_level': 1},
#   'publish': {'from': '2024-10-29T22:23:57.037+01:00',
#               'upto': '2024-11-05T21:26:00.000+01:00'},
#   'scope': {'lines': [{'designation': '17',
#                        'group_of_lines': 'tunnelbanans gröna linje',
#                        'id': 17,
#                        'name': 'Gröna linjen',
#                        'transport_authority': 1,
#                        'transport_mode': 'METRO'}],
#             'stop_areas': [{'id': 1951,
#                             'name': 'Skarpnäck',
#                             'transport_authority': 1,
#                             'type': 'METROSTN'}]},
#   'version': 2},
#  {'created': '2024-10-30T12:28:25.72+01:00',
#   'deviation_case_id': 4550071,
#   'message_variants': [{'details': 'Stopp för en avgång vid Skarpnäcks allé kl '
#                                    '12:13 mot Farsta strandplan på grund av '
#                                    'tekniskt fel.\n'
#                                    'Vi återkommer med mer information när vi '
#                                    'vet mer.\n',
#                         'header': 'Stopp vid Skarpnäcks allé',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 181'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-10-30T12:28:25.700+01:00',
#               'upto': '2024-10-30T13:05:00.000+01:00'},
#   'scope': {'lines': [{'designation': '181',
#                        'id': 181,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 13713,
#                             'name': 'Östmarksgatan',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 13150,
#                             'name': 'Farsta strandplan',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 13347,
#                             'name': 'Stora Sköndals väg',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 70603,
#                             'name': 'Kristinehamnsgatan',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 13617,
#                             'name': 'Dalbobranten',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 13621,
#                             'name': 'Diakongränd',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 70628,
#                             'name': 'Boforsgatan',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 13619,
#                             'name': 'Stora Sköndal',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 13624,
#                             'name': 'Sköndalsbro',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 13266,
#                             'name': 'Farsta centrum',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 70857,
#                             'name': 'Storforsplan',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 13264,
#                             'name': 'Farsta strand',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 13587,
#                             'name': 'Horisontvägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 13613,
#                             'name': 'Kubbegatan',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 13629,
#                             'name': 'Ågesta broväg',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 13579,
#                             'name': 'Kokoskakan',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 13602,
#                             'name': 'Norra Sköndal',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 13609,
#                             'name': 'Semmelvägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 13627,
#                             'name': 'Farsta sjukhem',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 13594,
#                             'name': 'Vinggatan',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 13647,
#                             'name': 'Säfflegatan',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 13615,
#                             'name': 'Sköndals centrum',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 13715,
#                             'name': 'Torsbygatan',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 13611,
#                             'name': 'Sköndalsskolan',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 13561,
#                             'name': 'Skarpnäcks allé',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 13592,
#                             'name': 'Skarpnäcksparken',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 13717,
#                             'name': 'Färnebogatan',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-10-30T05:35:42.1+01:00',
#   'deviation_case_id': 4545066,
#   'message_variants': [{'details': 'Kajplatsändring från kajplats 6 till '
#                                    'kajplats 3 för båt linje 83 från '
#                                    'Strömkajen kl 18:15 mot Grenadjärbryggan.',
#                         'header': 'Kajplatsändring',
#                         'language': 'sv',
#                         'scope_alias': 'Pendelbåt 83'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-10-30T05:35:42.097+01:00',
#               'upto': '2024-10-30T20:17:00.000+01:00'},
#   'scope': {'lines': [{'designation': '83',
#                        'group_of_lines': 'Pendelbåt',
#                        'id': 83,
#                        'transport_authority': 1,
#                        'transport_mode': 'SHIP'}]},
#   'version': 1},
#  {'created': '2024-10-30T11:36:08.117+01:00',
#   'deviation_case_id': 4549313,
#   'message_variants': [{'details': 'Vårby gård kl 10:41 till Lindvreten är '
#                                    'inställd pga tekniskt fel.',
#                         'header': 'Inställd avgång',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 740'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-10-30T11:36:08.110+01:00',
#               'upto': '2024-10-30T15:00:00.000+01:00'},
#   'scope': {'lines': [{'designation': '740',
#                        'id': 740,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 70720,
#                             'name': 'Pyramidbacken',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 70861,
#                             'name': 'Lindvreten',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 13304,
#                             'name': 'Måsholmstorget',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 70911,
#                             'name': 'Kungens kurva',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 70839,
#                             'name': 'IKEA södra',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 70833,
#                             'name': 'Mogårdsgången',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 70831,
#                             'name': 'Svanholmsvägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 70385,
#                             'name': 'Vårby gård',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 70714,
#                             'name': 'Vårberg',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 70320,
#                             'name': 'Skärholmen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 70393,
#                             'name': 'Ekholmsvägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 70400,
#                             'name': 'Ekgårdsvägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 70708,
#                             'name': 'Idholmsvägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 70863,
#                             'name': 'Apoteksbolaget',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 2},
#  {'created': '2023-03-21T14:34:59.2+01:00',
#   'deviation_case_id': 83046184,
#   'message_variants': [{'details': 'Buss linje 405, 409, 410, 411, 413, 414, '
#                                    '420, 422, 469, 492, 496 och 497 stannar '
#                                    'inte vid Sickla bro på grund av vägarbete '
#                                    'från och med 2023-03-27 kl 4:30.\n'
#                                    'Detta gäller till och med 2024-12-31 kl '
#                                    '23:59.\n'
#                                    'Du kan resa från hållplats Sickla Västra '
#                                    'alt. Alphyddan',
#                         'header': 'Indragen hållplats',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 405, 409, 410, 411, 413, 414, '
#                                        '420, 422, 469, 492, 496, 497'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2023-03-27T04:30:00.000+02:00',
#               'upto': '2024-12-31T23:59:00.000+01:00'},
#   'scope': {'lines': [{'designation': '413',
#                        'id': 413,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '409',
#                        'id': 409,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '411',
#                        'id': 411,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '469',
#                        'id': 469,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '497',
#                        'id': 497,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '420',
#                        'id': 420,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '405',
#                        'id': 405,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '422',
#                        'id': 422,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '496',
#                        'id': 496,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '414',
#                        'id': 414,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '492',
#                        'id': 492,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '410',
#                        'id': 410,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 40103,
#                             'name': 'Sickla bro',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-10-30T07:44:45.437+01:00',
#   'deviation_case_id': 4546893,
#   'message_variants': [{'details': 'Inställd avgång för buss linje 6 mellan '
#                                    'Stadsbiblioteket kl 7:16 och Karolinska '
#                                    'institutet Biomedicum är inställd pga '
#                                    'personalbrist.',
#                         'header': 'Inställd avgång',
#                         'language': 'sv',
#                         'scope_alias': 'Blåbuss 6'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-10-30T07:44:45.433+01:00',
#               'upto': '2024-10-31T00:00:00.000+01:00'},
#   'scope': {'lines': [{'designation': '6',
#                        'group_of_lines': 'blåbuss',
#                        'id': 6,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}]},
#   'version': 1},
#  {'created': '2024-10-29T11:24:25.94+01:00',
#   'deviation_case_id': 4238902,
#   'message_variants': [{'details': 'Hållplats Sävlången är flyttad 70 meter '
#                                    'bakåt i färdriktningen för buss linje 164 '
#                                    'mot Valla torg från och med 2024-10-07 pga '
#                                    'vägarbete.\n'
#                                    'Detta planeras pågå till och med '
#                                    '2024-11-15.',
#                         'header': 'Hållplats Sävlången flyttad',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 164'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-10-29T11:24:25.937+01:00',
#               'upto': '2024-11-15T17:00:00.000+01:00'},
#   'scope': {'lines': [{'designation': '164',
#                        'id': 164,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 13757,
#                             'name': 'Sävlången',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 2},
#  {'created': '2024-10-30T05:29:33.46+01:00',
#   'deviation_case_id': 4544987,
#   'message_variants': [{'details': 'Kajplatsändring från kajplats 3 till '
#                                    'kajplats 6 för båt linje 83 från '
#                                    'Strömkajen kl 17:30 mot Grenadjärbryggan.',
#                         'header': 'Kajplatsändring',
#                         'language': 'sv',
#                         'scope_alias': 'Pendelbåt 83'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-10-30T05:30:00.000+01:00',
#               'upto': '2024-10-30T19:40:00.000+01:00'},
#   'scope': {'lines': [{'designation': '83',
#                        'group_of_lines': 'Pendelbåt',
#                        'id': 83,
#                        'transport_authority': 1,
#                        'transport_mode': 'SHIP'}]},
#   'version': 2},
#  {'created': '2024-02-01T16:43:30.477+01:00',
#   'deviation_case_id': 1199954,
#   'message_variants': [{'details': 'Hållplats Strandbergsgatan är flyttad 110 '
#                                    'meter bakåt i färdriktningen för buss '
#                                    'linje 56 mot Hornsberg - Stora Essingen '
#                                    'och 74 mot Hornsberg - (SÖS) - Sickla udde '
#                                    'från och med 2024-02-05 pga '
#                                    'framkomlighetsproblem.\n'
#                                    'Detta planeras pågå till och med '
#                                    '2024-11-06.',
#                         'header': 'Hållplats Strandbergsgatan flyttad',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 56, 74'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-02-01T16:43:30.440+01:00',
#               'upto': '2024-11-06T23:59:00.000+01:00'},
#   'scope': {'lines': [{'designation': '56',
#                        'id': 56,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '74',
#                        'id': 74,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 10429,
#                             'name': 'Strandbergsgatan',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'categories': [{'group': 'FACILITY', 'type': 'LIFT'}],
#   'created': '2024-10-24T10:36:55.487+02:00',
#   'deviation_case_id': 4400395,
#   'message_variants': [{'details': 'Hissen vid Farsta är avstängd på grund av '
#                                    'tekniskt fel. Resenärer i behov av hiss '
#                                    'hänvisas till buss 181 och 833 till och '
#                                    'från Farsta strand, angränsande stationer '
#                                    'eller tillgänglighetsgarantin. \n'
#                                    '\n'
#                                    'Vi saknar prognos på när hissen åter kan '
#                                    'tas i bruk.\n',
#                         'header': 'Avstängd hiss vid Farsta',
#                         'language': 'sv',
#                         'scope_alias': 'Tunnelbanans gröna linje 18'}],
#   'priority': {'importance_level': 2, 'influence_level': 3, 'urgency_level': 1},
#   'publish': {'from': '2024-10-24T10:36:55.480+02:00',
#               'upto': '2024-10-31T13:35:00.000+01:00'},
#   'scope': {'lines': [{'designation': '18',
#                        'group_of_lines': 'tunnelbanans gröna linje',
#                        'id': 18,
#                        'name': 'Gröna linjen',
#                        'transport_authority': 1,
#                        'transport_mode': 'METRO'}],
#             'stop_areas': [{'id': 1871,
#                             'name': 'Farsta',
#                             'transport_authority': 1,
#                             'type': 'METROSTN'}]},
#   'version': 2},
#  {'created': '2024-08-23T17:52:47.42+02:00',
#   'deviation_case_id': 3772797,
#   'message_variants': [{'details': 'Buss linje 507 stannar inte vid Karolinska '
#                                    'sjukhuset norra och Solna kyrka på grund '
#                                    'av vägarbete från och med 2024-08-27 kl '
#                                    '20:00.\n'
#                                    'Detta gäller till och med 2025-03-28.\n'
#                                    'Resande mot Solna hänvisas till linje '
#                                    '506.\n'
#                                    'Resande mot Stockholm hänvisas till linje '
#                                    '3, 72 eller 77.',
#                         'header': 'Indragen hållplats',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 507'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-08-23T17:52:47.417+02:00',
#               'upto': '2025-03-28T23:59:00.000+01:00'},
#   'scope': {'lines': [{'designation': '507',
#                        'id': 507,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 50444,
#                             'name': 'Solna kyrka',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 50800,
#                             'name': 'Karolinska sjukhuset norra',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-09-25T15:39:19.917+02:00',
#   'deviation_case_id': 4145696,
#   'message_variants': [{'details': 'Hållplats Tegelbacken är flyttad till '
#                                    'Rödbodtorget samt Klara Mälarstrand för '
#                                    'buss linje 3 mot Karolinska sjukhuset - '
#                                    'Södersjukhuset, 3 mot Södersjukhuset - '
#                                    'Karolinska sjukhuset, 53 mot Karolinska '
#                                    'inst. - Henriksdalsberget och 53 mot '
#                                    'Henriksdalsberget - Karolinska inst från '
#                                    'och med 2024-09-25 pga vägarbete.\n'
#                                    'Detta planeras pågå till och med '
#                                    '2025-01-06.',
#                         'header': 'Hållplats Tegelbacken flyttad',
#                         'language': 'sv',
#                         'scope_alias': 'Blåbuss 3; Buss 53'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-09-25T15:39:19.903+02:00',
#               'upto': '2025-01-06T23:30:00.000+01:00'},
#   'scope': {'lines': [{'designation': '3',
#                        'group_of_lines': 'blåbuss',
#                        'id': 3,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '53',
#                        'id': 53,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 10383,
#                             'name': 'Tegelbacken',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-07-23T16:01:43.063+02:00',
#   'deviation_case_id': 3526589,
#   'message_variants': [{'details': 'Hållplats Beatelundsvägen är flyttad 120 '
#                                    'meter framåt i färdriktningen för buss '
#                                    'linje 428 mot Slussen, 429 mot Slussen, '
#                                    '430 mot Slussen och 467 mot Gustavsbergs '
#                                    'centrum från och med 2024-08-06 pga '
#                                    'vägarbete.\n'
#                                    'Detta planeras pågå till och med '
# ...
#                        'id': 821,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 40048,
#                             'name': 'Stavsborgsskolan',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 40049,
#                             'name': 'Älta centrum',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 40051,
#                             'name': 'Östra Stensö',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-10-21T10:46:58+02:00',
#   'deviation_case_id': 4441417,
#   'message_variants': [{'details': 'Hållplats Partihandlarvägen är flyttad 55 '
#                                    'meter framåt i färdriktningen för buss '
#                                    'linje 141 mot Telefonplan från och med '
#                                    '2024-10-23 pga vägarbete.\n'
#                                    'Detta planeras pågå till och med '
#                                    '2025-03-01.',
#                         'header': 'Hållplats Partihandlarvägen flyttad',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 141'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-10-23T06:00:00.000+02:00',
#               'upto': '2025-03-01T23:59:00.000+01:00'},
#   'scope': {'lines': [{'designation': '141',
#                        'id': 141,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 13193,
#                             'name': 'Partihandlarvägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-10-02T07:59:05.333+02:00',
#   'deviation_case_id': 4219770,
#   'message_variants': [{'details': 'Hållplats Vattugatan är tillfälligt '
#                                    'flyttad till Klara södra kyrkogata för '
#                                    'buss linje 809C mot Svartbäcken och 818C '
#                                    'mot Brandbergen från och med 2024-10-02 på '
#                                    'grund av vägarbete.\n'
#                                    'Detta planeras pågå till och med '
#                                    '2024-12-23.',
#                         'header': 'Hållplats Vattugatan flyttad',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 809, 818'}],
#   'priority': {'importance_level': 7, 'influence_level': 3, 'urgency_level': 1},
#   'publish': {'from': '2024-10-02T07:59:05.327+02:00',
#               'upto': '2024-12-23T23:00:00.000+01:00'},
#   'scope': {'lines': [{'designation': '818',
#                        'id': 818,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '809',
#                        'id': 809,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 80055,
#                             'name': 'Vattugatan',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 2},
#  {'created': '2024-01-03T07:45:54.66+01:00',
#   'deviation_case_id': 93075231,
#   'message_variants': [{'details': 'Buss linje 819, 823 och 824 stannar inte '
#                                    'vid Södergården från och med 2023-12-09 på '
#                                    'grund av kommande vägarbete.  Resenärer '
#                                    'hänvisas till hållplats Kumla skola. Detta '
#                                    'gäller i båda riktningar och beräknas pågå '
#                                    'till och med 2026.',
#                         'header': 'Indragna hållplatser',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 819, 823, 824'}],
#   'priority': {'importance_level': 7, 'influence_level': 3, 'urgency_level': 1},
#   'publish': {'from': '2024-01-03T07:45:54.647+01:00',
#               'upto': '2026-12-31T23:30:00.000+01:00'},
#   'scope': {'lines': [{'designation': '819',
#                        'id': 819,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '824',
#                        'id': 824,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '823',
#                        'id': 823,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 80351,
#                             'name': 'Södergården',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 2},
#  {'created': '2024-10-30T12:01:08.563+01:00',
#   'deviation_case_id': 4549879,
#   'message_variants': [{'details': 'Försening upp till 6 minuter för buss '
#                                    'linje 315 från Svanhagen kl 11:52 mot '
#                                    'Jäsängen på grund av sen anslutning.',
#                         'header': 'Försenad avgång',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 315'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-10-30T12:01:08.563+01:00',
#               'upto': '2024-10-30T13:00:00.000+01:00'},
#   'scope': {'lines': [{'designation': '315',
#                        'id': 315,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}]},
#   'version': 1},
#  {'created': '2024-07-31T17:25:45.37+02:00',
#   'deviation_case_id': 92660068,
#   'message_variants': [{'details': 'Hållplats Rågsvedsvägen är flyttad 40 '
#                                    'meter framåt  i färdriktningen för buss '
#                                    'linje 744 mot Högdalen från och med '
#                                    '2023-11-10 pga vägarbete.\n'
#                                    'Detta planeras pågå till och med '
#                                    '2025-03-05.',
#                         'header': 'Hållplats Rågsvedsvägen flyttad',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 744'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-07-31T17:25:45.363+02:00',
#               'upto': '2025-03-05T23:30:00.000+01:00'},
#   'scope': {'lines': [{'designation': '744',
#                        'id': 744,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 70593,
#                             'name': 'Rågsvedsvägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 2},
#  {'created': '2024-10-17T10:53:52.137+02:00',
#   'deviation_case_id': 4043183,
#   'message_variants': [{'details': 'Buss linje 165 stannar inte vid '
#                                    'Bedaröbacken, Flensvägen, Helgestavägen, '
#                                    'Aspövägen och Örby skola på grund av '
#                                    'framkomlighetsproblem från och med '
#                                    '2024-09-23 kl 5:30.\n'
#                                    'Detta gäller till och med 2024-10-31 kl '
#                                    '9:00.\n'
#                                    'Du kan resa från hållplats Årdalavägen, '
#                                    'Helgestasvägen',
#                         'header': 'Indragen hållplats',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 165'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-10-17T10:53:52.123+02:00',
#               'upto': '2024-10-31T09:00:00.000+01:00'},
#   'scope': {'lines': [{'designation': '165',
#                        'id': 165,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 14013,
#                             'name': 'Aspövägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 14007,
#                             'name': 'Bedaröbacken',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 14009,
#                             'name': 'Flensvägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 13045,
#                             'name': 'Örby skola',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 14011,
#                             'name': 'Helgestavägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 2},
#  {'created': '2024-05-23T11:05:44.33+02:00',
#   'deviation_case_id': 3024409,
#   'message_variants': [{'details': 'Buss linje 56 mot Hornsberg - Stora '
#                                    'Essingen och 65 mot Fredhäll - '
#                                    'Skeppsholmen stannar inte vid '
#                                    'Kellgrensgatan på grund av vägarbete från '
#                                    'och med 2024-06-03 kl 9:00.\n'
#                                    'Detta gäller till och med 2024-12-31 kl '
#                                    '23:59.\n'
#                                    'Du kan resa från hållplats S:t Görans '
#                                    'sjukhus',
#                         'header': 'Indragen hållplats',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 56, 65'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-06-03T09:00:56.000+02:00',
#               'upto': '2024-12-31T23:59:56.000+01:00'},
#   'scope': {'lines': [{'designation': '56',
#                        'id': 56,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '65',
#                        'id': 65,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 10426,
#                             'name': 'Kellgrensgatan',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 2},
#  {'created': '2024-10-17T04:57:58.29+02:00',
#   'deviation_case_id': 4395434,
#   'message_variants': [{'details': 'Hållplats Fjällnäsgatan är flyttad  75m  '
#                                    'bakåt  för buss linje 118 sedan kl 7:00 på '
#                                    'grund av vägarbete.\n'
#                                    '\n'
#                                    'Detta beräknas pågå till cirka kl 23:30.',
#                         'header': 'Hållplats Fjällnäsgatan flyttad',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 118'}],
#   'priority': {'importance_level': 5, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-10-17T07:00:00.000+02:00',
#               'upto': '2024-11-01T23:30:00.000+01:00'},
#   'scope': {'lines': [{'designation': '118',
#                        'id': 118,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 12303,
#                             'name': 'Fjällnäsgatan',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-10-21T05:56:06.277+02:00',
#   'deviation_case_id': 4437036,
#   'message_variants': [{'details': 'Hållplats Linvävartorpet är flyttad 25 '
#                                    'meter bakåt i färdrikningen för buss linje '
#                                    '515 mot Sundbybergs station-Odenplan, 526 '
#                                    'mot (Rudbecksskolan -) Sollentuna '
#                                    'stn-Karolinska sjukh, 592 mot '
#                                    'Arlanda-Stockholm C, 595 mot Sundbybergs '
#                                    'station-Stockholm C, 598 mot Upplands '
#                                    'Väsby-Stockholm C och 599 mot Stockholm '
#                                    'C-Brunnby-Vik från och med 2024-10-21 pga '
#                                    'vägarbete.\n'
#                                    'Detta planeras pågå till och med '
#                                    '2024-12-31.',
#                         'header': 'Hållplats Linvävartorpet flyttad',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 515, 526, 592, 595, 598, 599'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-10-21T05:56:06.267+02:00',
#               'upto': '2024-12-31T23:30:00.000+01:00'},
#   'scope': {'lines': [{'designation': '515',
#                        'id': 515,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '595',
#                        'id': 595,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '599',
#                        'id': 599,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '526',
#                        'id': 526,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '598',
#                        'id': 598,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '592',
#                        'id': 592,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 50007,
#                             'name': 'Linvävartorpet',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-09-24T10:29:38.727+02:00',
#   'deviation_case_id': 4130372,
#   'message_variants': [{'details': 'Buss linje 835 mot Vega/Länna handelsplats '
#                                    'stannar inte vid Södra Jordbrovägen på '
#                                    'grund av vägarbete. Resenärer hänvisas '
#                                    'till hållplats Nedergården.\n'
#                                    'Detta beräknas pågå till cirka 2024-12-20.',
#                         'header': 'Indragen hållplats',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 835'}],
#   'priority': {'importance_level': 7, 'influence_level': 3, 'urgency_level': 1},
#   'publish': {'from': '2024-10-05T05:00:00.000+02:00',
#               'upto': '2024-12-20T23:00:00.000+01:00'},
#   'scope': {'lines': [{'designation': '835',
#                        'id': 835,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 80799,
#                             'name': 'Södra Jordbrovägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1}]
