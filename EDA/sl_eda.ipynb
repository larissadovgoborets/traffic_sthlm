# %%
import requests
import pandas as pd
import pprint

# Define the API endpoint
# The full URL
# "https://deviations.integration.sl.se/v1/messages?future=<true/false>&site=<siteId1,siteId2>&line=<lineId1,lineId2>&transport_mode=<mode1,mode2>"

# The URL to include the future messages and not sort by other parameters
api_url = "https://deviations.integration.sl.se/v1/messages?future=true"

# Make a GET request to fetch the data
response = requests.get(api_url)

# Check if the request was successful
if response.status_code == 200:
    # Load the data into a pandas DataFrame
    data = response.json()
    print("Data fetched successfully!")
else:
    print(f"Failed to fetch data. Status code: {response.status_code}")

# Display the first few rows of the DataFrame

pprint.pprint(data)
# Out:
# Data fetched successfully!
# [{'created': '2024-10-30T10:39:58.453+01:00',
#   'deviation_case_id': 4549227,
#   'message_variants': [{'details': 'Hållplats Kvarnängsvägen är flyttad 175 '
#                                    'meter fram runt hörnet för buss linje 711 '
#                                    'mot Visättra sportcenter, 712 mot '
#                                    'Björnkulla, 713 mot Björnkulla och 794 mot '
#                                    'Visättra från och med 2024-10-30 pga '
#                                    'vägarbete.\n'
#                                    'Detta planeras pågå till och med '
#                                    '2024-12-31.',
#                         'header': 'Hållplats Kvarnängsvägen flyttad',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 711, 712, 713, 794'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-10-30T10:39:58.447+01:00',
#               'upto': '2024-12-31T23:30:00.000+01:00'},
#   'scope': {'lines': [{'designation': '711',
#                        'id': 711,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '712',
#                        'id': 712,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '713',
#                        'id': 713,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '794',
#                        'id': 794,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 70735,
#                             'name': 'Kvarnängsvägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-08-27T07:04:08.75+02:00',
#   'deviation_case_id': 3808782,
#   'message_variants': [{'details': 'Buss linje 507 stannar inte vid Karolinska '
#                                    'sjukhuset norra och Solna kyrka från och '
#                                    'med 2024-08-27 på grund av vägarbete.\n'
#                                    '\n'
#                                    'Detta beräknas pågå till och med '
#                                    '2025-03-28.\n'
#                                    '\n'
#                                    'Resinärer mot Solna hänvisas till linje '
#                                    '506 \n'
#                                    '\n'
#                                    'Resinärer mot Stockholm hänvisas till '
#                                    'linjer 3,72 eller 77',
#                         'header': 'Indragen hållplats',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 507'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-08-27T20:00:00.000+02:00',
#               'upto': '2025-03-28T04:30:00.000+01:00'},
#   'scope': {'lines': [{'designation': '507',
#                        'id': 507,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 50444,
#                             'name': 'Solna kyrka',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 50800,
#                             'name': 'Karolinska sjukhuset norra',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-10-30T16:10:36.33+01:00',
#   'deviation_case_id': 4552897,
#   'message_variants': [{'details': 'Hållplats Hallsta pappersbruk är flyttad '
#                                    '230m framåt i färdriktningen p.g.a. '
#                                    'vägarbete.\n'
#                                    '\n'
#                                    'Detta gäller från 2024-10-31 t.o.m. '
#                                    '2024-11-08.',
#                         'header': 'Flyttad hållplats.',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 639, 641, 643'}],
#   'priority': {'importance_level': 5, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-10-31T04:00:00.000+01:00',
#               'upto': '2024-11-08T23:59:00.000+01:00'},
#   'scope': {'lines': [{'designation': '639',
#                        'id': 639,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '641',
#                        'id': 641,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '643',
#                        'id': 643,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 64205,
#                             'name': 'Hallsta pappersbruk',
#                             'stop_points': [{'id': 64206,
#                                              'name': 'Hallsta pappersbruk'}],
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-10-28T11:31:37.293+01:00',
#   'deviation_case_id': 4522779,
#   'message_variants': [{'details': '697 Danderyds sjukhus\n'
#                                    'Hållplats  Lillhersbyvägen flyttas ca 80 '
#                                    'meter framåt mot Danderyds sjukhus p.g.a. '
#                                    'vägarbete.',
#                         'header': 'Flyttad hållplats',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 697'}],
#   'priority': {'importance_level': 5, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-10-29T07:00:00.000+01:00',
#               'upto': '2024-11-09T03:00:00.000+01:00'},
#   'scope': {'lines': [{'designation': '697',
#                        'id': 697,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 52332,
#                             'name': 'Lillhersbyvägen',
#                             'stop_points': [{'id': 52335,
#                                              'name': 'Lillhersbyvägen'}],
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-11-01T08:05:56.28+01:00',
#   'deviation_case_id': 4573845,
#   'message_variants': [{'details': 'Skärmarbrink - Skärmarbrink kl 8:03 är '
#                                    'inställd på grund av hala spår.',
#                         'header': 'Inställd avgång mot Skarpnäck',
#                         'language': 'sv',
#                         'scope_alias': 'Tunnelbanans gröna linje 17'}],
#   'priority': {'importance_level': 5, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-11-01T08:05:56.273+01:00',
#               'upto': '2024-11-01T09:05:00.000+01:00'},
#   'scope': {'lines': [{'designation': '17',
#                        'group_of_lines': 'tunnelbanans gröna linje',
#                        'id': 17,
#                        'name': 'Gröna linjen',
#                        'transport_authority': 1,
#                        'transport_mode': 'METRO'}],
#             'stop_areas': [{'id': 1601,
#                             'name': 'Skärmarbrink',
#                             'transport_authority': 1,
#                             'type': 'METROSTN'}]},
#   'version': 1},
#  {'created': '2024-11-01T08:36:27.76+01:00',
#   'deviation_case_id': 4574045,
#   'message_variants': [{'details': 'Avgången från Henriksdal kl 8:27 till '
#                                    'Slussen är c:a 10 minuter sen pga tekniskt '
#                                    'fel',
#                         'header': 'Försenad avgång',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 430'}],
#   'priority': {'importance_level': 5, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-11-01T08:36:27.753+01:00',
#               'upto': '2024-11-01T08:54:00.000+01:00'},
#   'scope': {'lines': [{'designation': '430',
#                        'id': 430,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 44000,
#                             'name': 'Slussen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 10595,
#                             'name': 'Henriksdal',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 10591,
#                             'name': 'Londonviadukten',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 2},
#  {'categories': [{'group': 'FACILITY', 'type': 'LIFT'}],
#   'created': '2024-10-21T12:08:55.177+02:00',
#   'deviation_case_id': 4441912,
#   'message_variants': [{'details': 'Hissen vid Hässelby strand är avstängd på '
#                                    'grund av underhållsarbete. Resenärer i '
#                                    'behov av hiss kan ta buss 119 till och '
#                                    'från Hässelby gård eller '
#                                    'tillgänglighetsgarantin.\n'
#                                    '\n'
#                                    'Hissen beräknas vara i drift igen den 16 '
#                                    'december.\n',
#                         'header': 'Avstängd hiss vid Hässelby strand',
#                         'language': 'sv',
#                         'scope_alias': 'Tunnelbanans gröna linje 17, 18, 19'}],
#   'priority': {'importance_level': 2, 'influence_level': 3, 'urgency_level': 1},
#   'publish': {'from': '2024-10-28T06:00:00.000+01:00',
#               'upto': '2024-12-16T18:00:00.000+01:00'},
#   'scope': {'lines': [{'designation': '19',
#                        'group_of_lines': 'tunnelbanans gröna linje',
#                        'id': 19,
#                        'name': 'Gröna linjen',
#                        'transport_authority': 1,
#                        'transport_mode': 'METRO'},
#                       {'designation': '17',
#                        'group_of_lines': 'tunnelbanans gröna linje',
#                        'id': 17,
#                        'name': 'Gröna linjen',
#                        'transport_authority': 1,
#                        'transport_mode': 'METRO'},
#                       {'designation': '18',
#                        'group_of_lines': 'tunnelbanans gröna linje',
#                        'id': 18,
#                        'name': 'Gröna linjen',
#                        'transport_authority': 1,
#                        'transport_mode': 'METRO'}],
#             'stop_areas': [{'id': 1331,
#                             'name': 'Hässelby strand',
#                             'transport_authority': 1,
#                             'type': 'METROSTN'}]},
#   'version': 3},
#  {'created': '2024-09-25T11:11:03.267+02:00',
#   'deviation_case_id': 4143437,
#   'message_variants': [{'details': 'Hållplatserna Campus Roslagen, '
#                                    'Gustavslund, Rösa trafikplats, Sätuna, '
#                                    'Västra Libby, Östra Libby  indragna.\n'
#                                    '\n'
#                                    'Tillagda hållplatser blir Husby vägskäl '
#                                    '(mot Finsta), Vallbyberg och Finsta '
#                                    'station.',
#                         'header': 'Indragen hållplats',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 653'}],
#   'priority': {'importance_level': 5, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-09-30T03:30:00.000+02:00',
#               'upto': '2025-09-26T05:50:00.000+02:00'},
#   'scope': {'lines': [{'designation': '653',
#                        'id': 653,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 62569,
#                             'name': 'Östra Libby',
#                             'stop_points': [{'id': 62570,
#                                              'name': 'Östra Libby'}],
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 62567,
#                             'name': 'Västra Libby',
#                             'stop_points': [{'id': 62567,
#                                              'name': 'Västra Libby'},
#                                             {'id': 62568,
#                                              'name': 'Västra Libby'}],
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 63054,
#                             'name': 'Rösa trafikplats',
#                             'stop_points': [{'id': 63054,
#                                              'name': 'Rösa trafikplats'},
#                                             {'id': 63055,
#                                              'name': 'Rösa trafikplats'}],
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 62573,
#                             'name': 'Gustavslund',
#                             'stop_points': [{'id': 62573,
#                                              'name': 'Gustavslund'},
#                                             {'id': 62574,
#                                              'name': 'Gustavslund'}],
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 64146,
#                             'name': 'Campus Roslagen',
#                             'stop_points': [{'id': 64902,
#                                              'name': 'Campus Roslagen'},
#                                             {'id': 64146,
#                                              'name': 'Campus Roslagen'}],
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 64727,
#                             'name': 'Sätuna',
#                             'stop_points': [{'id': 64728, 'name': 'Sätuna'},
#                                             {'id': 64727, 'name': 'Sätuna'}],
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-10-25T06:01:33.983+02:00',
#   'deviation_case_id': 2511163,
#   'message_variants': [{'details': 'Hållplats Skånska gården är flyttad 50 '
#                                    'meter bakåt i färdriktningen för buss '
#                                    'linje 421 mot Orminge centrum och 441 mot '
#                                    'Slussen från och med 2024-04-15 pga '
#                                    'vägarbete.\n'
#                                    'Detta planeras pågå till och med '
#                                    '2025-04-13.',
#                         'header': 'Hållplats Skånska gården flyttad',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 421, 441'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-10-25T06:01:33.977+02:00',
#               'upto': '2025-04-13T23:30:00.000+02:00'},
#   'scope': {'lines': [{'designation': '441',
#                        'id': 441,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '421',
#                        'id': 421,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 40485,
#                             'name': 'Skånska gården',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 3},
#  {'created': '2024-11-01T08:04:44.127+01:00',
#   'deviation_case_id': 4573825,
#   'message_variants': [{'details': 'Följande avgångar för Tvärbanan 30 stannar '
#                                    'ej vid Luma på grund av '
#                                    'sprängningsarbete:\n'
#                                    '\n'
#                                    'Från Luma mot Solna station kl 10:00.\n'
#                                    'Från Luma mot Sickla kl 10:00.\n'
#                                    'Resenärer till och från Luma hänvisas till '
#                                    'övriga avgångar. ',
#                         'header': 'Avgångar stannar ej vid Luma pga '
#                                   'sprängningsarbete',
#                         'language': 'sv',
#                         'scope_alias': 'Tvärbanan 30'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-11-01T08:04:44.100+01:00',
#               'upto': '2024-11-01T11:10:00.000+01:00'},
#   'scope': {'lines': [{'designation': '30',
#                        'group_of_lines': 'Tvärbanan',
#                        'id': 30,
#                        'name': 'Tvärbanan',
#                        'transport_authority': 1,
#                        'transport_mode': 'TRAM'}],
#             'stop_areas': [{'id': 4547,
#                             'name': 'Solna centrum',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4511,
#                             'name': 'Årstaberg',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4521,
#                             'name': 'Stora Essingen',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4501,
#                             'name': 'Gullmarsplan',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4539,
#                             'name': 'Karlsbodavägen',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4509,
#                             'name': 'Årstafältet',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4519,
#                             'name': 'Gröndal',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4537,
#                             'name': 'Norra Ulvsunda',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4545,
#                             'name': 'Solna Business Park',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4531,
#                             'name': 'Sickla kaj',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4543,
#                             'name': 'Sundbybergs centrum',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4513,
#                             'name': 'Årstadal',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4517,
#                             'name': 'Trekanten',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4505,
#                             'name': 'Linde',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4529,
#                             'name': 'Luma',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4503,
#                             'name': 'Globen',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4527,
#                             'name': 'Mårtensdal',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4535,
#                             'name': 'Johannesfred',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4523,
#                             'name': 'Alviks strand',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4533,
#                             'name': 'Sickla udde',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4549,
#                             'name': 'Solna station',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4507,
#                             'name': 'Valla torg',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 7615,
#                             'name': 'Sickla',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4541,
#                             'name': 'Bällsta bro',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4525,
#                             'name': 'Alvik',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4515,
#                             'name': 'Liljeholmen',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'}]},
#   'version': 1},
#  {'created': '2024-08-20T15:37:34.92+02:00',
#   'deviation_case_id': 3729665,
#   'message_variants': [{'details': 'Hållplats Münchenbryggeriet är flyttad '
#                                    'till ett tillfälligt läge på Torkel '
#                                    'Knutssonsgatan i båda färdriktningarna för '
#                                    'buss linje 405 från och med 2024-08-23 pga '
#                                    'vägarbete.\n'
#                                    'Detta planeras pågå till och med '
#                                    '2024-11-23.',
#                         'header': 'Hållplats Münchenbryggeriet flyttad',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 405'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-08-23T06:00:00.000+02:00',
#               'upto': '2024-11-23T23:59:00.000+01:00'},
#   'scope': {'lines': [{'designation': '405',
#                        'id': 405,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 10494,
#                             'name': 'Münchenbryggeriet',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-10-17T07:32:54.827+02:00',
#   'deviation_case_id': 4397238,
#   'message_variants': [{'details': 'Hållplats Enhagsslingan flyttad 160 meter '
#                                    'framåt.\n'
#                                    '\n'
#                                    'Hållplatsen tillgänglighetsanpassas. \n'
#                                    '\n'
#                                    'Gäller cirka 3 veckor.',
#                         'header': 'Flyttad hållplats',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 604'}],
#   'priority': {'importance_level': 5, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-10-17T07:32:54.823+02:00',
#               'upto': '2024-11-11T03:00:00.000+01:00'},
#   'scope': {'lines': [{'designation': '604',
#                        'id': 604,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 60425,
#                             'name': 'Enhagsslingan',
#                             'stop_points': [{'id': 60425,
#                                              'name': 'Enhagsslingan'}],
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-11-01T08:15:45.313+01:00',
#   'deviation_case_id': 4571768,
#   'message_variants': [{'details': 'Stopp i trafiken för Pendeltåg linje 48 '
#                                    'mellan Järna och Gnesta sedan kl 5:42 på '
#                                    'grund av elfel. \n'
#                                    '\n'
#                                    'Ersättnignsbuss trafikerar sträckan '
#                                    'Järna-Gnesta-Järna. \n'
#                                    '\n'
#                                    'Resenärer till och från Gnesta kan även '
#                                    'resa med Mälartåg med SL-biljett . Denna '
#                                    'biljettsamverkan gäller sträckan mellan '
#                                    'Gnesta och Stockholm central (och omvänt). '
#                                    'Mälartågen stannar vid Södertälje syd och '
#                                    'Flemingsberg.\n'
#                                    '\n'
#                                    'Pendeltågen går som vanligt mellan '
#                                    'Södertälje centrum och Järna trots att '
#                                    'reseplaneraren visar dem som inställda. '
#                                    'Enda undantag är acvgången från Södertälje '
#                                    'centrum kl. 09:01 som ersätts av buss helt '
#                                    'och hållet.\n'
#                                    '\n'
#                                    'Prognos saknas för när trafiken kan gå som '
#                                    'vanligt igen. \n'
#                                    '\n'
#                                    '\n'
#                                    'Sök din resa på sl.se eller i appen för '
#                                    'att hitta andra resvägar förbi stoppet. '
#                                    'Välj bort pendeltåg som färdmedel under '
#                                    'fliken Anpassa resefilter.',
#                         'header': 'Stopp mellan Järna och Gnesta',
#                         'language': 'sv',
#                         'scope_alias': 'Pendeltåg 48'}],
#   'priority': {'importance_level': 8, 'influence_level': 7, 'urgency_level': 1},
#   'publish': {'from': '2024-11-01T08:15:45.310+01:00',
#               'upto': '2024-11-01T13:00:00.000+01:00'},
#   'scope': {'lines': [{'designation': '48',
#                        'group_of_lines': 'Pendeltåg',
#                        'id': 48,
#                        'transport_authority': 1,
#                        'transport_mode': 'TRAIN'}],
#             'stop_areas': [{'id': 5271,
#                             'name': 'Gnesta',
#                             'transport_authority': 1,
#                             'type': 'RAILWSTN'},
#                            {'id': 5251,
#                             'name': 'Järna',
#                             'transport_authority': 1,
#                             'type': 'RAILWSTN'},
#                            {'id': 5261,
#                             'name': 'Mölnbo',
#                             'transport_authority': 1,
#                             'type': 'RAILWSTN'}]},
#   'version': 6},
#  {'created': '2024-10-02T02:13:36.797+02:00',
#   'deviation_case_id': 4217120,
#   'message_variants': [{'details': 'För  969 Färsna  är hållplatserna   '
#                                    'Drottninggatan, Norrtälje sjukhus  '
#                                    'indragna tillsvidare',
#                         'header': 'Indragen hållplats',
#                         'language': 'sv',
#                         'scope_alias': 'Närtrafiken 969'}],
#   'priority': {'importance_level': 5, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-10-02T02:13:36.790+02:00',
#               'upto': '2025-09-26T05:50:00.000+02:00'},
#   'scope': {'lines': [{'designation': '969',
#                        'group_of_lines': 'Närtrafiken',
#                        'id': 969,
#                        'name': 'Närtrafiken Norrtälje',
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 65037,
#                             'name': 'Norrtälje sjukhus',
#                             'stop_points': [{'id': 65037,
#                                              'name': 'Norrtälje sjukhus'}],
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 65035,
#                             'name': 'Drottninggatan',
#                             'stop_points': [{'id': 65035,
#                                              'name': 'Drottninggatan'}],
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-10-09T15:16:41.947+02:00',
#   'deviation_case_id': 4305855,
#   'message_variants': [{'details': 'Buss linje 854 stannar inte vid hållplats '
#                                    'Kullstaplan på Grönviksvägen.Bussar kör '
#                                    'omlagd körväg under byggtid och trafikerar '
#                                    'hållplatsen Kullstaplan  på Nynäsvägen i '
#                                    'båda riktningar sedan 2024-10-16 på grund '
#                                    'av vägarbete.\n'
#                                    'Detta beräknas pågå till cirka 2024-12-21.',
#                         'header': 'Indragen hållplats',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 854'}],
#   'priority': {'importance_level': 7, 'influence_level': 3, 'urgency_level': 1},
#   'publish': {'from': '2024-10-16T04:00:00.000+02:00',
#               'upto': '2024-12-21T23:30:00.000+01:00'},
#   'scope': {'lines': [{'designation': '854',
#                        'id': 854,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 75515,
#                             'name': 'Kullstaplan',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-07-25T17:05:30.603+02:00',
#   'deviation_case_id': 3540919,
#   'message_variants': [{'details': 'Vid Hökarängen kan sprängningsarbeten för '
#                                    'tunnelbanans utbyggnad utföras på vardagar '
#                                    'kl. 09:50-15:20, till och med 31 december. '
#                                    'Buller och vibrationer kan märkas både '
#                                    'inom och utanför stationen. De exakta '
#                                    'klockslag dessa sprängningar kan ske är '
#                                    'kl. 09:57, 10:27, 10:57, 11:57, 12:57, '
#                                    '13:27, 13:57 samt kl. 15:15.',
#                         'header': 'Sprängningsarbeten vid Hökarängen',
#                         'language': 'sv',
#                         'scope_alias': 'Tunnelbanans gröna linje 18'}],
#   'priority': {'importance_level': 2, 'influence_level': 3, 'urgency_level': 1},
#   'publish': {'from': '2024-08-01T07:45:00.000+02:00',
#               'upto': '2024-12-31T15:30:00.000+01:00'},
#   'scope': {'lines': [{'designation': '18',
#                        'group_of_lines': 'tunnelbanans gröna linje',
#                        'id': 18,
#                        'name': 'Gröna linjen',
#                        'transport_authority': 1,
#                        'transport_mode': 'METRO'}],
#             'stop_areas': [{'id': 1861,
#                             'name': 'Hökarängen',
#                             'transport_authority': 1,
#                             'type': 'METROSTN'}]},
#   'version': 1},
#  {'created': '2024-10-30T10:15:21.08+01:00',
#   'deviation_case_id': 3167038,
#   'message_variants': [{'details': 'Hållplats Tullingebergsvägen är flyttad 60 '
#                                    'meter bakåt i färdriktningen för buss '
#                                    'linje 723 mot Tullinge station från och '
#                                    'med 2024-06-10 pga vägarbete.\n'
#                                    'Detta planeras pågå till och med '
#                                    '2024-11-15.',
#                         'header': 'Hållplats Tullingebergsvägen flyttad',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 723'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-10-30T10:15:21.073+01:00',
#               'upto': '2024-11-15T16:00:00.000+01:00'},
#   'scope': {'lines': [{'designation': '723',
#                        'id': 723,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 70208,
#                             'name': 'Tullingebergsvägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 3},
#  {'created': '2024-10-30T10:13:40.08+01:00',
#   'deviation_case_id': 4548948,
#   'message_variants': [{'details': 'Hållplats Sky City/Terminal 4 och 5 \n'
#                                    'använder tillfälligt yttre hållplatsläget '
#                                    'för Arlanda SkyCity p.g.a. '
#                                    'asfalteringsarbete.',
#                         'header': 'Flyttad hållplats',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 579, 583, 589, 593'}],
#   'priority': {'importance_level': 5, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-11-04T03:00:00.000+01:00',
#               'upto': '2024-11-07T03:00:00.000+01:00'},
#   'scope': {'lines': [{'designation': '579',
#                        'id': 579,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '583',
#                        'id': 583,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '589',
#                        'id': 589,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '593',
#                        'id': 593,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 57342,
#                             'name': 'Sky City/Terminal 4 och 5',
#                             'stop_points': [{'id': 57342,
#                                              'name': 'Sky City/Terminal 4 och '
#                                                      '5'}],
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-11-01T07:27:20.587+01:00',
#   'deviation_case_id': 4573303,
#   'message_variants': [{'details': 'Försening upp till 8 minuter för buss '
#                                    'linje 748 från Liljeholmen kl 7:49 mot '
#                                    'Södertälje centrum på grund av tidigare '
#                                    'stopp.',
#                         'header': 'Försenad avgång',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 748'}],
#   'priority': {'importance_level': 7, 'influence_level': 3, 'urgency_level': 1},
#   'publish': {'from': '2024-11-01T07:42:00.000+01:00',
#               'upto': '2024-11-01T09:11:00.000+01:00'},
#   'scope': {'lines': [{'designation': '748',
#                        'id': 748,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}]},
#   'version': 1},
#  {'created': '2024-09-05T15:35:12.893+02:00',
#   'deviation_case_id': 3615684,
#   'message_variants': [{'details': 'Vid Stadshagen är entrén från '
#                                    'Mariedalsvägen/Hornsberg stängd på grund '
#                                    'av underhållsarbete. \n'
#                                    '\n'
#                                    'Hänvisning till uppgången mot Sankt '
#                                    'Göransgatan/Kellgrensgatan.\n'
#                                    '\n'
#                                    'Arbetet beräknas pågå t.o.m. hösten 2024.',
#                         'header': 'Entré vid Stadshagen stängd',
#                         'language': 'sv',
#                         'scope_alias': 'Tunnelbanans blå linje 10, 11'}],
#   'priority': {'importance_level': 2, 'influence_level': 3, 'urgency_level': 1},
#   'publish': {'from': '2024-09-05T15:35:12.890+02:00',
#               'upto': '2024-12-31T18:00:00.000+01:00'},
#   'scope': {'lines': [{'designation': '10',
#                        'group_of_lines': 'tunnelbanans blå linje',
#                        'id': 10,
#                        'name': 'Blå linjen',
#                        'transport_authority': 1,
#                        'transport_mode': 'METRO'},
#                       {'designation': '11',
#                        'group_of_lines': 'tunnelbanans blå linje',
#                        'id': 11,
#                        'name': 'Blå linjen',
#                        'transport_authority': 1,
#                        'transport_mode': 'METRO'}],
#             'stop_areas': [{'id': 3161,
#                             'name': 'Stadshagen',
#                             'transport_authority': 1,
#                             'type': 'METROSTN'}]},
#   'version': 4},
#  {'created': '2023-03-21T14:34:59.2+01:00',
#   'deviation_case_id': 83046184,
#   'message_variants': [{'details': 'Buss linje 405, 409, 410, 411, 413, 414, '
#                                    '420, 422, 469, 492, 496 och 497 stannar '
#                                    'inte vid Sickla bro på grund av vägarbete '
#                                    'från och med 2023-03-27 kl 4:30.\n'
#                                    'Detta gäller till och med 2024-12-31 kl '
#                                    '23:59.\n'
#                                    'Du kan resa från hållplats Sickla Västra '
#                                    'alt. Alphyddan',
#                         'header': 'Indragen hållplats',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 405, 409, 410, 411, 413, 414, '
#                                        '420, 422, 469, 492, 496, 497'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2023-03-27T04:30:00.000+02:00',
#               'upto': '2024-12-31T23:59:00.000+01:00'},
#   'scope': {'lines': [{'designation': '413',
#                        'id': 413,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '409',
#                        'id': 409,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '411',
#                        'id': 411,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '469',
#                        'id': 469,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '497',
#                        'id': 497,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '420',
#                        'id': 420,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '405',
#                        'id': 405,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '422',
#                        'id': 422,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '496',
#                        'id': 496,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '414',
#                        'id': 414,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '492',
#                        'id': 492,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '410',
#                        'id': 410,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 40103,
#                             'name': 'Sickla bro',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-10-29T11:24:25.94+01:00',
#   'deviation_case_id': 4238902,
#   'message_variants': [{'details': 'Hållplats Sävlången är flyttad 70 meter '
#                                    'bakåt i färdriktningen för buss linje 164 '
#                                    'mot Valla torg från och med 2024-10-07 pga '
#                                    'vägarbete.\n'
#                                    'Detta planeras pågå till och med '
#                                    '2024-11-15.',
#                         'header': 'Hållplats Sävlången flyttad',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 164'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-10-29T11:24:25.937+01:00',
#               'upto': '2024-11-15T17:00:00.000+01:00'},
#   'scope': {'lines': [{'designation': '164',
#                        'id': 164,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 13757,
#                             'name': 'Sävlången',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 2},
#  {'created': '2024-02-01T16:43:30.477+01:00',
#   'deviation_case_id': 1199954,
#   'message_variants': [{'details': 'Hållplats Strandbergsgatan är flyttad 110 '
#                                    'meter bakåt i färdriktningen för buss '
#                                    'linje 56 mot Hornsberg - Stora Essingen '
#                                    'och 74 mot Hornsberg - (SÖS) - Sickla udde '
#                                    'från och med 2024-02-05 pga '
#                                    'framkomlighetsproblem.\n'
#                                    'Detta planeras pågå till och med '
#                                    '2024-11-06.',
#                         'header': 'Hållplats Strandbergsgatan flyttad',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 56, 74'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-02-01T16:43:30.440+01:00',
#               'upto': '2024-11-06T23:59:00.000+01:00'},
#   'scope': {'lines': [{'designation': '56',
#                        'id': 56,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '74',
#                        'id': 74,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 10429,
#                             'name': 'Strandbergsgatan',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-08-23T17:52:47.42+02:00',
#   'deviation_case_id': 3772797,
#   'message_variants': [{'details': 'Buss linje 507 stannar inte vid Karolinska '
#                                    'sjukhuset norra och Solna kyrka på grund '
#                                    'av vägarbete från och med 2024-08-27 kl '
#                                    '20:00.\n'
#                                    'Detta gäller till och med 2025-03-28.\n'
#                                    'Resande mot Solna hänvisas till linje '
#                                    '506.\n'
#                                    'Resande mot Stockholm hänvisas till linje '
#                                    '3, 72 eller 77.',
#                         'header': 'Indragen hållplats',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 507'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-08-23T17:52:47.417+02:00',
#               'upto': '2025-03-28T23:59:00.000+01:00'},
#   'scope': {'lines': [{'designation': '507',
#                        'id': 507,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 50444,
#                             'name': 'Solna kyrka',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 50800,
#                             'name': 'Karolinska sjukhuset norra',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-09-25T15:39:19.917+02:00',
#   'deviation_case_id': 4145696,
#   'message_variants': [{'details': 'Hållplats Tegelbacken är flyttad till '
#                                    'Rödbodtorget samt Klara Mälarstrand för '
#                                    'buss linje 3 mot Karolinska sjukhuset - '
#                                    'Södersjukhuset, 3 mot Södersjukhuset - '
#                                    'Karolinska sjukhuset, 53 mot Karolinska '
#                                    'inst. - Henriksdalsberget och 53 mot '
#                                    'Henriksdalsberget - Karolinska inst från '
#                                    'och med 2024-09-25 pga vägarbete.\n'
#                                    'Detta planeras pågå till och med '
#                                    '2025-01-06.',
#                         'header': 'Hållplats Tegelbacken flyttad',
#                         'language': 'sv',
#                         'scope_alias': 'Blåbuss 3; Buss 53'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-09-25T15:39:19.903+02:00',
#               'upto': '2025-01-06T23:30:00.000+01:00'},
#   'scope': {'lines': [{'designation': '3',
#                        'group_of_lines': 'blåbuss',
#                        'id': 3,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '53',
# ...
#   'scope': {'lines': [{'designation': '14',
#                        'group_of_lines': 'tunnelbanans röda linje',
#                        'id': 14,
#                        'name': 'Röda linjen',
#                        'transport_authority': 1,
#                        'transport_mode': 'METRO'}],
#             'stop_areas': [{'id': 2831,
#                             'name': 'Hägerstensåsen',
#                             'transport_authority': 1,
#                             'type': 'METROSTN'}]},
#   'version': 1},
#  {'created': '2024-07-31T17:25:45.37+02:00',
#   'deviation_case_id': 92660068,
#   'message_variants': [{'details': 'Hållplats Rågsvedsvägen är flyttad 40 '
#                                    'meter framåt  i färdriktningen för buss '
#                                    'linje 744 mot Högdalen från och med '
#                                    '2023-11-10 pga vägarbete.\n'
#                                    'Detta planeras pågå till och med '
#                                    '2025-03-05.',
#                         'header': 'Hållplats Rågsvedsvägen flyttad',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 744'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-07-31T17:25:45.363+02:00',
#               'upto': '2025-03-05T23:30:00.000+01:00'},
#   'scope': {'lines': [{'designation': '744',
#                        'id': 744,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 70593,
#                             'name': 'Rågsvedsvägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 2},
#  {'created': '2024-05-23T11:05:44.33+02:00',
#   'deviation_case_id': 3024409,
#   'message_variants': [{'details': 'Buss linje 56 mot Hornsberg - Stora '
#                                    'Essingen och 65 mot Fredhäll - '
#                                    'Skeppsholmen stannar inte vid '
#                                    'Kellgrensgatan på grund av vägarbete från '
#                                    'och med 2024-06-03 kl 9:00.\n'
#                                    'Detta gäller till och med 2024-12-31 kl '
#                                    '23:59.\n'
#                                    'Du kan resa från hållplats S:t Görans '
#                                    'sjukhus',
#                         'header': 'Indragen hållplats',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 56, 65'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-06-03T09:00:56.000+02:00',
#               'upto': '2024-12-31T23:59:56.000+01:00'},
#   'scope': {'lines': [{'designation': '56',
#                        'id': 56,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '65',
#                        'id': 65,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 10426,
#                             'name': 'Kellgrensgatan',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 2},
#  {'created': '2024-11-01T08:11:47.257+01:00',
#   'deviation_case_id': 4573926,
#   'message_variants': [{'details': 'Avgången från Södertörns högskola kl 8:01 '
#                                    'till Tumba station är c:a 10 minuter sen '
#                                    'pga tekniskt fel',
#                         'header': 'Försenad avgång',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 713'}],
#   'priority': {'importance_level': 5, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-11-01T08:11:47.233+01:00',
#               'upto': '2024-11-01T08:55:00.000+01:00'},
#   'scope': {'lines': [{'designation': '713',
#                        'id': 713,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 70259,
#                             'name': 'Norrskensbacken',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 72332,
#                             'name': 'Tullinge centrum',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 70188,
#                             'name': 'Kittelvägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 72394,
#                             'name': 'Riddarvägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 70245,
#                             'name': 'Falks backe',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 70936,
#                             'name': 'Trågstigen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 70192,
#                             'name': 'Bokvägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 72336,
#                             'name': 'Petunievägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 70235,
#                             'name': 'Tullingeberg',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 70253,
#                             'name': 'Skyttbrink',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 70237,
#                             'name': 'Vallmovägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 70645,
#                             'name': 'Bryggarvägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 70186,
#                             'name': 'Huddinge sjukhus',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 72330,
#                             'name': 'Elgentorpsvägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 70249,
#                             'name': 'Bernströmsvägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 70258,
#                             'name': 'Tumba station',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 70210,
#                             'name': 'Månstorpsvägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 70482,
#                             'name': 'Södertörns högskola',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 70175,
#                             'name': 'Solskensvägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 72338,
#                             'name': 'Blickavägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 70239,
#                             'name': 'Tullingebergsbacken',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 70255,
#                             'name': 'Hamrabron',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 70934,
#                             'name': 'Kavlevägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 72396,
#                             'name': 'Dymmelkärrsvägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 70251,
#                             'name': 'Gjuteriet',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-10-17T04:57:58.29+02:00',
#   'deviation_case_id': 4395434,
#   'message_variants': [{'details': 'Hållplats Fjällnäsgatan är flyttad  75m  '
#                                    'bakåt  för buss linje 118 sedan kl 7:00 på '
#                                    'grund av vägarbete.\n'
#                                    '\n'
#                                    'Detta beräknas pågå till cirka kl 23:30.',
#                         'header': 'Hållplats Fjällnäsgatan flyttad',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 118'}],
#   'priority': {'importance_level': 5, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-10-17T07:00:00.000+02:00',
#               'upto': '2024-11-01T23:30:00.000+01:00'},
#   'scope': {'lines': [{'designation': '118',
#                        'id': 118,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 12303,
#                             'name': 'Fjällnäsgatan',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-11-01T07:50:08.823+01:00',
#   'deviation_case_id': 4573642,
#   'message_variants': [{'details': 'Islandstorget - Islandstorget kl 7:46 är '
#                                    'inställd på grund av hala spår.',
#                         'header': 'Inställd avgång mot Vällingby',
#                         'language': 'sv',
#                         'scope_alias': 'Tunnelbanans gröna linje 18'}],
#   'priority': {'importance_level': 5, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-11-01T07:50:08.820+01:00',
#               'upto': '2024-11-01T08:49:00.000+01:00'},
#   'scope': {'lines': [{'designation': '18',
#                        'group_of_lines': 'tunnelbanans gröna linje',
#                        'id': 18,
#                        'name': 'Gröna linjen',
#                        'transport_authority': 1,
#                        'transport_mode': 'METRO'}],
#             'stop_areas': [{'id': 1261,
#                             'name': 'Islandstorget',
#                             'transport_authority': 1,
#                             'type': 'METROSTN'}]},
#   'version': 1},
#  {'created': '2024-10-21T05:56:06.277+02:00',
#   'deviation_case_id': 4437036,
#   'message_variants': [{'details': 'Hållplats Linvävartorpet är flyttad 25 '
#                                    'meter bakåt i färdrikningen för buss linje '
#                                    '515 mot Sundbybergs station-Odenplan, 526 '
#                                    'mot (Rudbecksskolan -) Sollentuna '
#                                    'stn-Karolinska sjukh, 592 mot '
#                                    'Arlanda-Stockholm C, 595 mot Sundbybergs '
#                                    'station-Stockholm C, 598 mot Upplands '
#                                    'Väsby-Stockholm C och 599 mot Stockholm '
#                                    'C-Brunnby-Vik från och med 2024-10-21 pga '
#                                    'vägarbete.\n'
#                                    'Detta planeras pågå till och med '
#                                    '2024-12-31.',
#                         'header': 'Hållplats Linvävartorpet flyttad',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 515, 526, 592, 595, 598, 599'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-10-21T05:56:06.267+02:00',
#               'upto': '2024-12-31T23:30:00.000+01:00'},
#   'scope': {'lines': [{'designation': '515',
#                        'id': 515,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '595',
#                        'id': 595,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '599',
#                        'id': 599,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '526',
#                        'id': 526,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '598',
#                        'id': 598,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '592',
#                        'id': 592,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 50007,
#                             'name': 'Linvävartorpet',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-09-24T10:29:38.727+02:00',
#   'deviation_case_id': 4130372,
#   'message_variants': [{'details': 'Buss linje 835 mot Vega/Länna handelsplats '
#                                    'stannar inte vid Södra Jordbrovägen på '
#                                    'grund av vägarbete. Resenärer hänvisas '
#                                    'till hållplats Nedergården.\n'
#                                    'Detta beräknas pågå till cirka 2024-12-20.',
#                         'header': 'Indragen hållplats',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 835'}],
#   'priority': {'importance_level': 7, 'influence_level': 3, 'urgency_level': 1},
#   'publish': {'from': '2024-10-05T05:00:00.000+02:00',
#               'upto': '2024-12-20T23:00:00.000+01:00'},
#   'scope': {'lines': [{'designation': '835',
#                        'id': 835,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 80799,
#                             'name': 'Södra Jordbrovägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-11-01T07:50:51.41+01:00',
#   'deviation_case_id': 4573646,
#   'message_variants': [{'details': 'Avgången från Danderyds sjukhus kl 7:45 '
#                                    'till Lunda industri är cirka 6 minuter '
#                                    'försenad pga framkomlighetsproblem.',
#                         'header': 'Ny avgångstid',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 157'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-11-01T07:50:51.407+01:00',
#               'upto': '2024-11-01T08:41:00.000+01:00'},
#   'scope': {'lines': [{'designation': '157',
#                        'id': 157,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}]},
#   'version': 1}]
