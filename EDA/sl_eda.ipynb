# %%
import requests
import pprint

# Define the API endpoint
# The full URL
# "https://deviations.integration.sl.se/v1/messages?future=<true/false>&site=<siteId1,siteId2>&line=<lineId1,lineId2>&transport_mode=<mode1,mode2>"

# The URL to include the future messages and not filter by other parameters
api_url = "https://deviations.integration.sl.se/v1/messages?future=true"

# Make a GET request to fetch the data
response = requests.get(api_url)

# Check if the request was successful
if response.status_code == 200:
    # Load the data into a pandas DataFrame
    data = response.json()
    print("Data fetched successfully!")
else:
    print(f"Failed to fetch data. Status code: {response.status_code}")

# Display the first few rows of the DataFrame

pprint.pprint(data)
# Out:
# Data fetched successfully!
# [{'created': '2024-10-30T10:39:58.453+01:00',
#   'deviation_case_id': 4549227,
#   'message_variants': [{'details': 'Hållplats Kvarnängsvägen är flyttad 175 '
#                                    'meter fram runt hörnet för buss linje 711 '
#                                    'mot Visättra sportcenter, 712 mot '
#                                    'Björnkulla, 713 mot Björnkulla och 794 mot '
#                                    'Visättra från och med 2024-10-30 pga '
#                                    'vägarbete.\n'
#                                    'Detta planeras pågå till och med '
#                                    '2024-12-31.',
#                         'header': 'Hållplats Kvarnängsvägen flyttad',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 711, 712, 713, 794'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-10-30T10:39:58.447+01:00',
#               'upto': '2024-12-31T23:30:00.000+01:00'},
#   'scope': {'lines': [{'designation': '711',
#                        'id': 711,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '712',
#                        'id': 712,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '713',
#                        'id': 713,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '794',
#                        'id': 794,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 70735,
#                             'name': 'Kvarnängsvägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-12-18T11:51:55.327+01:00',
#   'deviation_case_id': 5137343,
#   'message_variants': [{'details': 'Försening upp till 6 minuter för buss '
#                                    'linje 176 från Mörby station kl 11:07 mot '
#                                    'Solbacka på grund av '
#                                    'framkomlighetsproblem.',
#                         'header': 'Försenad avgång',
#                         'language': 'sv',
#                         'scope_alias': 'Blåbuss 176'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-12-18T11:51:55.313+01:00',
#               'upto': '2024-12-18T12:54:00.000+01:00'},
#   'scope': {'lines': [{'designation': '176',
#                        'group_of_lines': 'blåbuss',
#                        'id': 176,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}]},
#   'version': 1},
#  {'created': '2024-12-16T10:22:54.52+01:00',
#   'deviation_case_id': 4355817,
#   'message_variants': [{'details': 'Buss linje 821 mot Tyresö centrum stannar '
#                                    'inte vid Stavsborgsskolan, Älta centrum '
#                                    'och Östra Stensö från och med  2024-10-14 '
#                                    'på grund av vägarbete. Resenärer hänvisas '
#                                    'till alternativa hållplats Ekstubben.\n'
#                                    'Detta beräknas pågå till och med  '
#                                    '2025-01-24.',
#                         'header': 'Indragen hållplats',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 821'}],
#   'priority': {'importance_level': 7, 'influence_level': 3, 'urgency_level': 1},
#   'publish': {'from': '2024-12-16T10:22:54.513+01:00',
#               'upto': '2025-01-24T23:30:00.000+01:00'},
#   'scope': {'lines': [{'designation': '821',
#                        'id': 821,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 40048,
#                             'name': 'Stavsborgsskolan',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 40049,
#                             'name': 'Älta centrum',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 40051,
#                             'name': 'Östra Stensö',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 2},
#  {'created': '2024-04-26T06:06:15.29+02:00',
#   'deviation_case_id': 2765132,
#   'message_variants': [{'details': 'På linje  646 Rimbo har hållplats Alhamra '
#                                    'flyttats 60 meter bakåt. \n'
#                                    ' \n'
#                                    'Detta gäller fr.o.m. 2024-04-24 och '
#                                    'tillsvidare.',
#                         'header': 'Hållplats flyttad',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 646'}],
#   'priority': {'importance_level': 5, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-04-26T06:06:15.280+02:00',
#               'upto': '2025-04-26T06:00:00.000+02:00'},
#   'scope': {'lines': [{'designation': '646',
#                        'id': 646,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 64615,
#                             'name': 'Alhamra',
#                             'stop_points': [{'id': 64615, 'name': 'Alhamra'}],
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-12-18T12:24:54.803+01:00',
#   'deviation_case_id': 5136340,
#   'message_variants': [{'details': 'Förseningar på upp mot 20 minuter för '
#                                    'Pendeltåg linje 43X på grund av tidigare '
#                                    'signalfel mellan Nynäsgård och Ösmo.\n'
#                                    '\n'
#                                    'Prognos saknas för när trafiken kan gå '
#                                    'enligt tidtabell igen.\n'
#                                    '\n'
#                                    'Tåg kan ställas in eller köra förbi vissa '
#                                    'stationer med kort varsel. Var uppmärksam '
#                                    'på plattformsskyltar och utrop ombord på '
#                                    'tågen.',
#                         'header': 'Förseningar på grund av tidigare signalfel',
#                         'language': 'sv',
#                         'scope_alias': 'Pendeltåg 43'}],
#   'priority': {'importance_level': 7, 'influence_level': 7, 'urgency_level': 1},
#   'publish': {'from': '2024-12-18T12:24:54.800+01:00',
#               'upto': '2024-12-18T14:00:00.000+01:00'},
#   'scope': {'lines': [{'designation': '43',
#                        'group_of_lines': 'Pendeltåg',
#                        'id': 43,
#                        'transport_authority': 1,
#                        'transport_mode': 'TRAIN'}]},
#   'version': 4},
#  {'created': '2024-09-25T11:11:03.267+02:00',
#   'deviation_case_id': 4143437,
#   'message_variants': [{'details': 'Hållplatserna Campus Roslagen, '
#                                    'Gustavslund, Rösa trafikplats, Sätuna, '
#                                    'Västra Libby, Östra Libby  indragna.\n'
#                                    '\n'
#                                    'Tillagda hållplatser blir Husby vägskäl '
#                                    '(mot Finsta), Vallbyberg och Finsta '
#                                    'station.',
#                         'header': 'Indragen hållplats',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 653'}],
#   'priority': {'importance_level': 5, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-09-30T03:30:00.000+02:00',
#               'upto': '2025-09-26T05:50:00.000+02:00'},
#   'scope': {'lines': [{'designation': '653',
#                        'id': 653,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 62569,
#                             'name': 'Östra Libby',
#                             'stop_points': [{'id': 62570,
#                                              'name': 'Östra Libby'}],
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 62567,
#                             'name': 'Västra Libby',
#                             'stop_points': [{'id': 62567,
#                                              'name': 'Västra Libby'},
#                                             {'id': 62568,
#                                              'name': 'Västra Libby'}],
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 63054,
#                             'name': 'Rösa trafikplats',
#                             'stop_points': [{'id': 63054,
#                                              'name': 'Rösa trafikplats'},
#                                             {'id': 63055,
#                                              'name': 'Rösa trafikplats'}],
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 62573,
#                             'name': 'Gustavslund',
#                             'stop_points': [{'id': 62573,
#                                              'name': 'Gustavslund'},
#                                             {'id': 62574,
#                                              'name': 'Gustavslund'}],
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 64146,
#                             'name': 'Campus Roslagen',
#                             'stop_points': [{'id': 64902,
#                                              'name': 'Campus Roslagen'},
#                                             {'id': 64146,
#                                              'name': 'Campus Roslagen'}],
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 64727,
#                             'name': 'Sätuna',
#                             'stop_points': [{'id': 64728, 'name': 'Sätuna'},
#                                             {'id': 64727, 'name': 'Sätuna'}],
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-12-03T12:17:39.637+01:00',
#   'deviation_case_id': 4956756,
#   'message_variants': [{'details': 'Fr.o.m. 15 december får linje 630 en ny '
#                                    'avgång på vardagar i vardera riktningen, '
#                                    'med avgångstid 17:40 från Norrtälje '
#                                    'busstation och 18:14 från Spillersboda',
#                         'header': 'Ändring av tidtabell',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 630'}],
#   'priority': {'importance_level': 5, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-12-03T12:17:39.633+01:00',
#               'upto': '2024-12-31T13:17:00.000+01:00'},
#   'scope': {'lines': [{'designation': '630',
#                        'id': 630,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}]},
#   'version': 1},
#  {'created': '2024-10-25T06:01:33.983+02:00',
#   'deviation_case_id': 2511163,
#   'message_variants': [{'details': 'Hållplats Skånska gården är flyttad 50 '
#                                    'meter bakåt i färdriktningen för buss '
#                                    'linje 421 mot Orminge centrum och 441 mot '
#                                    'Slussen från och med 2024-04-15 pga '
#                                    'vägarbete.\n'
#                                    'Detta planeras pågå till och med '
#                                    '2025-04-13.',
#                         'header': 'Hållplats Skånska gården flyttad',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 421, 441'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-10-25T06:01:33.977+02:00',
#               'upto': '2025-04-13T23:30:00.000+02:00'},
#   'scope': {'lines': [{'designation': '441',
#                        'id': 441,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '421',
#                        'id': 421,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 40485,
#                             'name': 'Skånska gården',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 3},
#  {'categories': [{'group': 'FACILITY', 'type': 'LIFT'}],
#   'created': '2024-12-18T09:41:38.683+01:00',
#   'deviation_case_id': 5136041,
#   'message_variants': [{'details': 'Hissen vid Rinkeby mellan biljetthallen '
#                                    'och mellanplan är avstängd på grund av '
#                                    'tekniskt fel. Resenärer i behov av hiss '
#                                    'hänvisas till angränsande stationer eller '
#                                    'tillgänglighetsgarantin. \n'
#                                    '\n'
#                                    'Vi saknar prognos på när hissen åter kan '
#                                    'tas i bruk.\n',
#                         'header': 'Avstängd hiss vid Rinkeby',
#                         'language': 'sv',
#                         'scope_alias': 'Tunnelbanans blå linje 10'}],
#   'priority': {'importance_level': 2, 'influence_level': 3, 'urgency_level': 1},
#   'publish': {'from': '2024-12-18T09:41:38.680+01:00',
#               'upto': '2025-01-01T10:40:00.000+01:00'},
#   'scope': {'lines': [{'designation': '10',
#                        'group_of_lines': 'tunnelbanans blå linje',
#                        'id': 10,
#                        'name': 'Blå linjen',
#                        'transport_authority': 1,
#                        'transport_mode': 'METRO'}],
#             'stop_areas': [{'id': 3461,
#                             'name': 'Rinkeby',
#                             'transport_authority': 1,
#                             'type': 'METROSTN'}]},
#   'version': 1},
#  {'created': '2024-12-03T11:28:57.69+01:00',
#   'deviation_case_id': 4956412,
#   'message_variants': [{'details': 'Fr.o.m. 15 december utökas trafiken på '
#                                    'linje 584 med fler avgångar dagtid',
#                         'header': 'Utökad trafik',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 584'}],
#   'priority': {'importance_level': 5, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-12-03T11:28:57.690+01:00',
#               'upto': '2024-12-31T12:26:00.000+01:00'},
#   'scope': {'lines': [{'designation': '584',
#                        'id': 584,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}]},
#   'version': 1},
#  {'created': '2020-12-23T10:21:33.043+01:00',
#   'deviation_case_id': 35875144,
#   'message_variants': [{'details': 'Buss linje 865 mot Skärholmen stannar inte '
#                                    'vid Mogårdsvägen sedan kl 0:00 på grund av '
#                                    'vägarbete.\n'
#                                    'Detta beräknas pågå tills vidare. '
#                                    'Resenärer hänvisas till Vårby gård. ',
#                         'header': 'Indragen hållplats',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 865'}],
#   'priority': {'importance_level': 7, 'influence_level': 3, 'urgency_level': 1},
#   'publish': {'from': '2020-12-23T10:21:33.037+01:00',
#               'upto': '2025-01-01T23:00:00.000+01:00'},
#   'scope': {'lines': [{'designation': '865',
#                        'group_of_lines': 'Buss',
#                        'id': 865,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 70865,
#                             'name': 'Mogårdsvägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-07-25T17:05:30.603+02:00',
#   'deviation_case_id': 3540919,
#   'message_variants': [{'details': 'Vid Hökarängen kan sprängningsarbeten för '
#                                    'tunnelbanans utbyggnad utföras på vardagar '
#                                    'kl. 09:50-15:20, till och med 31 december. '
#                                    'Buller och vibrationer kan märkas både '
#                                    'inom och utanför stationen. De exakta '
#                                    'klockslag dessa sprängningar kan ske är '
#                                    'kl. 09:57, 10:27, 10:57, 11:57, 12:57, '
#                                    '13:27, 13:57 samt kl. 15:15.',
#                         'header': 'Sprängningsarbeten vid Hökarängen',
#                         'language': 'sv',
#                         'scope_alias': 'Tunnelbanans gröna linje 18'}],
#   'priority': {'importance_level': 2, 'influence_level': 3, 'urgency_level': 1},
#   'publish': {'from': '2024-08-01T07:45:00.000+02:00',
#               'upto': '2024-12-31T15:30:00.000+01:00'},
#   'scope': {'lines': [{'designation': '18',
#                        'group_of_lines': 'tunnelbanans gröna linje',
#                        'id': 18,
#                        'name': 'Gröna linjen',
#                        'transport_authority': 1,
#                        'transport_mode': 'METRO'}],
#             'stop_areas': [{'id': 1861,
#                             'name': 'Hökarängen',
#                             'transport_authority': 1,
#                             'type': 'METROSTN'}]},
#   'version': 1},
#  {'created': '2024-11-18T10:59:14.757+01:00',
#   'deviation_case_id': 4767908,
#   'message_variants': [{'details': 'Hållplats Återlöga är flyttad 60 meter '
#                                    'bakåt i färdriktningen för buss linje 430 '
#                                    'mot Gustavsbergs centrum från och med '
#                                    '2024-11-20 pga halka.\n'
#                                    'Detta planeras pågå till och med '
#                                    '2025-04-07.',
#                         'header': 'Hållplats Återlöga flyttad',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 430'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-11-20T09:00:00.000+01:00',
#               'upto': '2025-04-07T09:00:00.000+02:00'},
#   'scope': {'lines': [{'designation': '430',
#                        'id': 430,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 41261,
#                             'name': 'Återlöga',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-12-02T05:18:41.653+01:00',
#   'deviation_case_id': 4938371,
#   'message_variants': [{'details': 'Hållplats Härjedalsgatan är flyttad 30 '
#                                    'meter bakåt för buss linje 116 mot '
#                                    'Vällingby-Spånga station, 179 mot '
#                                    'Sollentuna station-Vällingby och 199 mot '
#                                    'Hallonbergen-Vällingby sedan kl 7:00 på '
#                                    'grund av vägarbete.\n'
#                                    '\n',
#                         'header': 'Hållplats Härjedalsgatan flyttad',
#                         'language': 'sv',
#                         'scope_alias': 'Blåbuss 179; Buss 116, 199'}],
#   'priority': {'importance_level': 5, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-12-04T07:00:00.000+01:00',
#               'upto': '2024-12-20T23:30:00.000+01:00'},
#   'scope': {'lines': [{'designation': '199',
#                        'id': 199,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '116',
#                        'id': 116,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '179',
#                        'group_of_lines': 'blåbuss',
#                        'id': 179,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 12452,
#                             'name': 'Härjedalsgatan',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-11-18T10:43:15.07+01:00',
#   'deviation_case_id': 4767792,
#   'message_variants': [{'details': 'Hållplats Foresta är flyttad 40 meter '
#                                    'framåt i färdriktningen för buss linje 238 '
#                                    'mot Högsätra - Larsbergs brygga - Näset '
#                                    'och 923 mot Servicelinje Lidingö från och '
#                                    'med 2024-11-19 pga väderleksförhållanden.\n'
#                                    'Detta planeras pågå till och med '
#                                    '2025-03-31.',
#                         'header': 'Hållplats Foresta flyttad',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 238; Närtrafiken 923'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-11-19T14:00:00.000+01:00',
#               'upto': '2025-03-31T09:00:00.000+02:00'},
#   'scope': {'lines': [{'designation': '238',
#                        'id': 238,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '923',
#                        'group_of_lines': 'Närtrafiken',
#                        'id': 923,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 20971,
#                             'name': 'Foresta',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-12-18T11:42:55.717+01:00',
#   'deviation_case_id': 5137268,
#   'message_variants': [{'details': 'Försening upp till 10 minuter för buss '
#                                    'linje 751 från Torekällberget kl 11:40, '
#                                    '11:55 mot Södertälje centrum på grund av '
#                                    'halka.',
#                         'header': 'Försenad avgång',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 751'}],
#   'priority': {'importance_level': 7, 'influence_level': 3, 'urgency_level': 1},
#   'publish': {'from': '2024-12-18T11:42:55.710+01:00',
#               'upto': '2024-12-18T12:35:00.000+01:00'},
#   'scope': {'lines': [{'designation': '751',
#                        'id': 751,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}]},
#   'version': 1},
#  {'created': '2024-11-08T11:39:16.557+01:00',
#   'deviation_case_id': 4657996,
#   'message_variants': [{'details': 'Hållplats Strandbergsgatan är flyttad 110 '
#                                    'meter bakåt i färdriktningen för buss '
#                                    'linje 56 mot Hornsberg - Stora Essingen '
#                                    'och 74 mot Hornsberg - (SÖS) - Sickla udde '
#                                    'från och med 2024-11-11 pga vägarbete.\n'
#                                    'Detta planeras pågå till och med '
#                                    '2025-01-15.',
#                         'header': 'Hållplats Strandbergsgatan flyttad',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 56, 74'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-11-11T05:30:00.000+01:00',
#               'upto': '2025-01-15T23:30:00.000+01:00'},
#   'scope': {'lines': [{'designation': '56',
#                        'id': 56,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '74',
#                        'id': 74,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 10429,
#                             'name': 'Strandbergsgatan',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-10-23T06:13:39.817+02:00',
#   'deviation_case_id': 4464186,
#   'message_variants': [{'details': 'Hållplats Understensvägen är flyttad 40 '
#                                    'meter bakåt i färdriktningen för buss '
#                                    'linje 194 mot Stockholm C från och med '
#                                    '2024-10-23 pga vägarbete.\n'
#                                    'Detta planeras pågå till och med '
#                                    '2025-10-09.',
#                         'header': 'Hållplats Understensvägen flyttad',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 194'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-10-23T07:00:00.000+02:00',
#               'upto': '2025-10-09T23:30:00.000+02:00'},
#   'scope': {'lines': [{'designation': '194',
#                        'id': 194,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 13877,
#                             'name': 'Understensvägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-03-20T14:25:31.657+01:00',
#   'deviation_case_id': 2147886,
#   'message_variants': [{'details': 'Buss linje 156 stannar inte vid '
#                                    'Vintergatan, Gjuteribacken och Tritonvägen '
#                                    'sedan 2024-03-20 kl 14:23 på grund av '
#                                    'vägarbete.',
#                         'header': 'Indragna hållplatser',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 156'}],
#   'priority': {'importance_level': 7, 'influence_level': 3, 'urgency_level': 1},
#   'publish': {'from': '2024-03-20T14:25:31.647+01:00',
#               'upto': '2024-12-31T23:30:00.000+01:00'},
#   'scope': {'lines': [{'designation': '156',
#                        'id': 156,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 50301,
#                             'name': 'Vintergatan',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 50241,
#                             'name': 'Gjuteribacken',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 50240,
#                             'name': 'Tritonvägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-12-18T12:01:22.45+01:00',
#   'deviation_case_id': 5137429,
#   'message_variants': [{'details': 'Hållplats Flygstigen, Hägernäs station '
#                                    'indragen p.g.a. framkomlighetsproblem.',
#                         'header': 'Indragen hållplats',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 604'}],
#   'priority': {'importance_level': 5, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-12-18T12:01:22.447+01:00',
#               'upto': '2024-12-18T16:00:00.000+01:00'},
#   'scope': {'lines': [{'designation': '604',
#                        'id': 604,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 61748,
#                             'name': 'Hägernäs station',
#                             'stop_points': [{'id': 61748,
#                                              'name': 'Hägernäs station'}],
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'},
#                            {'id': 61788,
#                             'name': 'Flygstigen',
#                             'stop_points': [{'id': 61789, 'name': 'Flygstigen'},
#                                             {'id': 61788,
#                                              'name': 'Flygstigen'}],
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-11-18T11:11:08.05+01:00',
#   'deviation_case_id': 4768006,
#   'message_variants': [{'details': 'Hållplats Inteckningsvägen är flyttad 134 '
#                                    'meter framåt i färdriktningen för buss '
#                                    'linje 147 mot Liljeholmen och 192 mot '
#                                    'Stockholm C från och med 2024-11-19 pga '
#                                    'halka.\n'
#                                    'Detta planeras pågå till och med '
#                                    '2025-03-31.',
#                         'header': 'Hållplats Inteckningsvägen flyttad',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 147, 192'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-11-19T07:00:00.000+01:00',
#               'upto': '2025-03-31T12:00:00.000+02:00'},
#   'scope': {'lines': [{'designation': '147',
#                        'id': 147,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '192',
#                        'id': 192,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 13521,
#                             'name': 'Inteckningsvägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-12-18T11:52:32.377+01:00',
#   'deviation_case_id': 5137346,
#   'message_variants': [{'details': 'Försening upp till 6 minuter för buss '
#                                    'linje 176 från Solbacka kl 11:26 mot Mörby '
#                                    'station på grund av framkomlighetsproblem.',
#                         'header': 'Försenad avgång',
#                         'language': 'sv',
#                         'scope_alias': 'Blåbuss 176'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-12-18T11:52:32.373+01:00',
#               'upto': '2024-12-18T13:10:00.000+01:00'},
#   'scope': {'lines': [{'designation': '176',
#                        'group_of_lines': 'blåbuss',
#                        'id': 176,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}]},
#   'version': 1},
#  {'created': '2024-11-05T13:40:38.867+01:00',
#   'deviation_case_id': 4018571,
#   'message_variants': [{'details': 'Hållplats Kullerstensvägen är flyttad 10 '
#                                    'meter fram för buss linje 837 mot Vega '
#                                    'station och 892 mot Stockholms C från och '
#                                    'med 2024-09-13 på grund av vägarbete.\n'
#                                    '\n'
#                                    'Detta planeras pågå till och med '
#                                    '2024-12-20.',
#                         'header': 'Hållplats Kullerstensvägen flyttad',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 837, 892'}],
#   'priority': {'importance_level': 5, 'influence_level': 3, 'urgency_level': 1},
#   'publish': {'from': '2024-11-05T13:40:38.860+01:00',
#               'upto': '2024-12-20T23:30:00.000+01:00'},
#   'scope': {'lines': [{'designation': '892',
#                        'id': 892,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '837',
#                        'id': 837,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 80817,
#                             'name': 'Kullerstensvägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 3},
#  {'created': '2024-05-29T19:15:17.497+02:00',
#   'deviation_case_id': 3097879,
#   'message_variants': [{'details': 'Hållplats S:t Eriksgatan är flyttad 100 '
#                                    'meter framåt i färdriktningen för blåbuss '
#                                    'linje 6 mot Ropsten och buss linje 53 mot '
#                                    'Henriksdalsberget och 72 mot Frihamnen '
#                                    'från och med 2024-05-31 pga vägarbete.\n'
#                                    'Detta planeras pågå till och med '
#                                    '2024-12-31.',
#                         'header': 'Hållplats S:t Eriksgatan flyttad',
#                         'language': 'sv',
#                         'scope_alias': 'Blåbuss 6; Buss 53, 72'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-05-31T05:30:00.000+02:00',
#               'upto': '2024-12-31T23:59:00.000+01:00'},
#   'scope': {'lines': [{'designation': '6',
#                        'group_of_lines': 'blåbuss',
#                        'id': 6,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '53',
#                        'id': 53,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '72',
#                        'id': 72,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 10180,
#                             'name': 'S:t Eriksgatan',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-11-05T13:35:51.56+01:00',
#   'deviation_case_id': 4619253,
#   'message_variants': [{'details': 'Hållplats Karolinska sjukhuset '
#                                    'Eugeniavägen är flyttad 38 meter bakåt i '
#                                    'färdriktningen för buss linje 77 mot '
#                                    'Liljeholmen - Karolinska sjukhuset från '
#                                    'och med 2024-11-06 pga vägarbete.\n'
#                                    'Detta planeras pågå till och med '
#                                    '2025-05-30.',
#                         'header': 'Hållplats Karolinska sjukhuset Eugeniavägen '
#                                   'flyttad',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 77'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-11-06T05:00:00.000+01:00',
#               'upto': '2025-05-30T23:30:00.000+02:00'},
#   'scope': {'lines': [{'designation': '77',
#                        'id': 77,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 10357,
#                             'name': 'Karolinska sjukhuset Eugeniavägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-12-02T09:11:19.37+01:00',
#   'deviation_case_id': 4941743,
#   'message_variants': [{'details': 'Hållplats Östermalmstorg är flyttad 30 '
#                                    'meter bakåt i färdriktningen för buss '
#                                    'linje 57 mot Sofia från och med 2024-12-06 '
#                                    'pga vägarbete.\n'
#                                    'Detta planeras pågå till och med '
#                                    '2025-01-17.',
#                         'header': 'Hållplats Östermalmstorg flyttad',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 57'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-12-06T06:00:00.000+01:00',
#               'upto': '2025-01-17T17:00:00.000+01:00'},
#   'scope': {'lines': [{'designation': '57',
#                        'id': 57,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 10915,
#                             'name': 'Östermalmstorg',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-12-18T11:53:37.593+01:00',
#   'deviation_case_id': 5137358,
#   'message_variants': [{'details': 'Försening upp till 6 minuter för buss '
#                                    'linje 176 från Solbacka kl 11:40 mot Mörby '
#                                    'station på grund av framkomlighetsproblem.',
#                         'header': 'Försenad avgång',
#                         'language': 'sv',
#                         'scope_alias': 'Blåbuss 176'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-12-18T11:53:37.590+01:00',
#               'upto': '2024-12-18T13:24:00.000+01:00'},
#   'scope': {'lines': [{'designation': '176',
#                        'group_of_lines': 'blåbuss',
#                        'id': 176,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}]},
#   'version': 1},
#  {'created': '2024-12-18T11:41:11.087+01:00',
#   'deviation_case_id': 5137252,
#   'message_variants': [{'details': 'Försening på 5 minuter för Tvärbanan 30 '
#                                    'från Sickla kaj kl 11:35 mot Solna station '
#                                    'på grund av vagnfel.',
#                         'header': 'Försenad avgång',
#                         'language': 'sv',
#                         'scope_alias': 'Tvärbanan 30'}],
#   'priority': {'importance_level': 5, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-12-18T11:41:11.067+01:00',
#               'upto': '2024-12-18T12:47:00.000+01:00'},
#   'scope': {'lines': [{'designation': '30',
#                        'group_of_lines': 'Tvärbanan',
#                        'id': 30,
#                        'name': 'Tvärbanan',
#                        'transport_authority': 1,
#                        'transport_mode': 'TRAM'}],
#             'stop_areas': [{'id': 4545,
#                             'name': 'Solna Business Park',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4513,
#                             'name': 'Årstadal',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4547,
#                             'name': 'Solna centrum',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4515,
#                             'name': 'Liljeholmen',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4517,
#                             'name': 'Trekanten',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4549,
#                             'name': 'Solna station',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4519,
#                             'name': 'Gröndal',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4521,
#                             'name': 'Stora Essingen',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4523,
#                             'name': 'Alviks strand',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4525,
#                             'name': 'Alvik',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4527,
#                             'name': 'Mårtensdal',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4529,
#                             'name': 'Luma',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4531,
#                             'name': 'Sickla kaj',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4501,
#                             'name': 'Gullmarsplan',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4503,
#                             'name': 'Globen',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4535,
#                             'name': 'Johannesfred',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4505,
#                             'name': 'Linde',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4537,
#                             'name': 'Norra Ulvsunda',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4539,
#                             'name': 'Karlsbodavägen',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4507,
#                             'name': 'Valla torg',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4509,
#                             'name': 'Årstafältet',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4541,
#                             'name': 'Bällsta bro',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4511,
#                             'name': 'Årstaberg',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'},
#                            {'id': 4543,
#                             'name': 'Sundbybergs centrum',
#                             'transport_authority': 1,
#                             'type': 'TRAMSTN'}]},
#   'version': 1},
#  {'created': '2024-12-04T10:27:54.673+01:00',
#   'deviation_case_id': 4970292,
#   'message_variants': [{'details': 'Fr.o.m. 15 december förlängs Linje 574 '
#                                    'från Husby Långhundra kyrka till '
#                                    'Långhundra Åby vägskäl',
#                         'header': 'Utökning av rutt',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 574'}],
#   'priority': {'importance_level': 5, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-12-04T10:27:54.663+01:00',
#               'upto': '2024-12-31T00:51:00.000+01:00'},
#   'scope': {'lines': [{'designation': '574',
#                        'id': 574,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}]},
#   'version': 1},
#  {'created': '2024-12-16T10:55:47.563+01:00',
#   'deviation_case_id': 4305855,
#   'message_variants': [{'details': 'Buss linje 854 stannar inte vid hållplats '
#                                    'Kullstaplan på Grönviksvägen.Bussar kör '
#                                    'omlagd körväg under byggtid och trafikerar '
#                                    'hållplatsen Kullstaplan  på Nynäsvägen i '
#                                    'båda riktningar sedan 2024-10-16 på grund '
#                                    'av vägarbete.\n'
#                                    'Detta beräknas pågå till cirka 2024-12-21.',
#                         'header': 'Indragen hållplats',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 854'}],
#   'priority': {'importance_level': 7, 'influence_level': 3, 'urgency_level': 1},
#   'publish': {'from': '2024-12-16T10:55:47.560+01:00',
#               'upto': '2025-01-17T23:30:00.000+01:00'},
#   'scope': {'lines': [{'designation': '854',
#                        'id': 854,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 75515,
#                             'name': 'Kullstaplan',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 2},
#  {'created': '2024-12-02T05:03:32.417+01:00',
#   'deviation_case_id': 4938267,
#   'message_variants': [{'details': 'Hållplats Handelshögskolan är flyttad 6 '
#                                    'meter bakåt för buss linje 516 mot Sergels '
#                                    'torg-Häggvik sedan kl 7:00 på grund av '
#                                    'framkomlighetsproblem.\n'
#                                    '\n'
#                                    '.',
#                         'header': 'Hållplats Handelshögskolan flyttad',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 516'}],
#   'priority': {'importance_level': 5, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-12-02T07:00:00.000+01:00',
#               'upto': '2024-12-18T23:30:00.000+01:00'},
#   'scope': {'lines': [{'designation': '516',
#                        'id': 516,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 10545,
#                             'name': 'Handelshögskolan',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-05-29T19:11:32.097+02:00',
#   'deviation_case_id': 3097834,
#   'message_variants': [{'details': 'Hållplats S:t Eriksgatan är flyttad 120 '
#                                    'meter bakåt i färdriktningen för buss '
#                                    'linje 53 mot Karolinska institutet och 72 '
# ...
#                         'scope_alias': 'Buss 141'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-10-23T06:00:00.000+02:00',
#               'upto': '2025-03-01T23:59:00.000+01:00'},
#   'scope': {'lines': [{'designation': '141',
#                        'id': 141,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 13193,
#                             'name': 'Partihandlarvägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-12-03T13:42:59.24+01:00',
#   'deviation_case_id': 4957423,
#   'message_variants': [{'details': 'Fr.o.m. 15 december börjar linje 697 '
#                                    'trafikera hållplatsläge B i Mörby centrum',
#                         'header': 'Ändrat hållplatsläge',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 697'}],
#   'priority': {'importance_level': 5, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-12-03T13:42:59.237+01:00',
#               'upto': '2024-12-31T13:04:00.000+01:00'},
#   'scope': {'lines': [{'designation': '697',
#                        'id': 697,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 60017,
#                             'name': 'Mörby centrum',
#                             'stop_points': [{'id': 60103,
#                                              'name': 'Mörby centrum'}],
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2023-03-21T14:34:59.2+01:00',
#   'deviation_case_id': 83046184,
#   'message_variants': [{'details': 'Buss linje 405, 409, 410, 411, 413, 414, '
#                                    '420, 422, 469, 492, 496 och 497 stannar '
#                                    'inte vid Sickla bro på grund av vägarbete '
#                                    'från och med 2023-03-27 kl 4:30.\n'
#                                    'Detta gäller till och med 2024-12-31 kl '
#                                    '23:59.\n'
#                                    'Du kan resa från hållplats Sickla Västra '
#                                    'alt. Alphyddan',
#                         'header': 'Indragen hållplats',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 405, 409, 410, 411, 413, 414, '
#                                        '420, 422, 469, 492, 496, 497'}],
#   'priority': {'importance_level': 7, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2023-03-27T04:30:00.000+02:00',
#               'upto': '2024-12-31T23:59:00.000+01:00'},
#   'scope': {'lines': [{'designation': '413',
#                        'id': 413,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '409',
#                        'id': 409,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '411',
#                        'id': 411,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '469',
#                        'id': 469,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '497',
#                        'id': 497,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '420',
#                        'id': 420,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '405',
#                        'id': 405,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '422',
#                        'id': 422,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '496',
#                        'id': 496,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '414',
#                        'id': 414,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '492',
#                        'id': 492,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '410',
#                        'id': 410,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 40103,
#                             'name': 'Sickla bro',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'categories': [{'group': 'FACILITY', 'type': 'LIFT'}],
#   'created': '2024-12-16T10:06:08.74+01:00',
#   'deviation_case_id': 5110909,
#   'message_variants': [{'details': 'Hissen mot plattformen mot Akalla och '
#                                    'Hjulsta Västra skogen är avstängd på grund '
#                                    'av tekniskt fel. Resenärer i behov av hiss '
#                                    'hänvisas till angränsande stationer eller '
#                                    'tillgänglighetsgarantin. \n'
#                                    '\n'
#                                    'Vi saknar prognos på när hissen åter kan '
#                                    'tas i bruk.\n',
#                         'header': 'Avstängd hiss vid Västra skogen',
#                         'language': 'sv',
#                         'scope_alias': 'Tunnelbanans blå linje 10, 11'}],
#   'priority': {'importance_level': 2, 'influence_level': 3, 'urgency_level': 1},
#   'publish': {'from': '2024-12-16T10:06:08.733+01:00',
#               'upto': '2024-12-30T11:05:10.163+01:00'},
#   'scope': {'lines': [{'designation': '10',
#                        'group_of_lines': 'tunnelbanans blå linje',
#                        'id': 10,
#                        'name': 'Blå linjen',
#                        'transport_authority': 1,
#                        'transport_mode': 'METRO'},
#                       {'designation': '11',
#                        'group_of_lines': 'tunnelbanans blå linje',
#                        'id': 11,
#                        'name': 'Blå linjen',
#                        'transport_authority': 1,
#                        'transport_mode': 'METRO'}],
#             'stop_areas': [{'id': 3201,
#                             'name': 'Västra skogen',
#                             'transport_authority': 1,
#                             'type': 'METROSTN'}]},
#   'version': 1},
#  {'created': '2024-04-11T06:13:57.237+02:00',
#   'deviation_case_id': 2556535,
#   'message_variants': [{'details': 'Buss linje 592, 598 och 599 stannar inte '
#                                    'vid Rotsunda torg   på grund av '
#                                    'framkomlighetsproblem.\n'
#                                    '\n'
#                                    'Gäller tillsvidare.',
#                         'header': 'Indragna hållplatser',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 592, 598, 599'}],
#   'priority': {'importance_level': 7, 'influence_level': 3, 'urgency_level': 1},
#   'publish': {'from': '2024-04-11T06:13:57.227+02:00',
#               'upto': '2024-12-31T23:30:00.000+01:00'},
#   'scope': {'lines': [{'designation': '599',
#                        'id': 599,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '592',
#                        'id': 592,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '598',
#                        'id': 598,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 50544,
#                             'name': 'Rotsunda torg',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 2},
#  {'created': '2024-01-03T07:45:54.66+01:00',
#   'deviation_case_id': 93075231,
#   'message_variants': [{'details': 'Buss linje 819, 823 och 824 stannar inte '
#                                    'vid Södergården från och med 2023-12-09 på '
#                                    'grund av kommande vägarbete.  Resenärer '
#                                    'hänvisas till hållplats Kumla skola. Detta '
#                                    'gäller i båda riktningar och beräknas pågå '
#                                    'till och med 2026.',
#                         'header': 'Indragna hållplatser',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 819, 823, 824'}],
#   'priority': {'importance_level': 7, 'influence_level': 3, 'urgency_level': 1},
#   'publish': {'from': '2024-01-03T07:45:54.647+01:00',
#               'upto': '2026-12-31T23:30:00.000+01:00'},
#   'scope': {'lines': [{'designation': '819',
#                        'id': 819,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '824',
#                        'id': 824,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'},
#                       {'designation': '823',
#                        'id': 823,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 80351,
#                             'name': 'Södergården',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 2},
#  {'created': '2024-12-04T09:10:54.28+01:00',
#   'deviation_case_id': 4969444,
#   'message_variants': [{'details': 'Hållplats Karlbergsskolan flyttad 50 meter '
#                                    'bakåt i riktning Uthamra p.g.a. vägarbete.',
#                         'header': 'Flyttad hållplats',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 664'}],
#   'priority': {'importance_level': 5, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-12-04T09:10:54.277+01:00',
#               'upto': '2025-01-31T23:59:00.000+01:00'},
#   'scope': {'lines': [{'designation': '664',
#                        'id': 664,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 66514,
#                             'name': 'Karlbergsskolan',
#                             'stop_points': [{'id': 66514,
#                                              'name': 'Karlbergsskolan'}],
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2024-11-14T14:51:29.79+01:00',
#   'deviation_case_id': 4728970,
#   'message_variants': [{'details': 'Hållplats Ensta krog dras in from 15 april '
#                                    '- ca. juli 2025.\n'
#                                    '\n'
#                                    'Resenärer hänvisas till hållplats '
#                                    'Åkerbyvägen Norra, ca 400 meter bakåt i '
#                                    'linjesträckningen.',
#                         'header': 'Indragna hållplatser',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 614'}],
#   'priority': {'importance_level': 5, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-11-14T14:51:29.787+01:00',
#               'upto': '2025-07-01T03:30:00.000+02:00'},
#   'scope': {'lines': [{'designation': '614',
#                        'id': 614,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 61939,
#                             'name': 'Ensta krog',
#                             'stop_points': [{'id': 61939,
#                                              'name': 'Ensta krog'}],
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1},
#  {'created': '2023-12-08T10:12:47.69+01:00',
#   'deviation_case_id': 89602579,
#   'message_variants': [{'details': 'Buss linje 502 stannar inte vid '
#                                    'Pyramidvägen  på grund av vägarbete.',
#                         'header': 'Indragen hållplats',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 502'}],
#   'priority': {'importance_level': 7, 'influence_level': 3, 'urgency_level': 1},
#   'publish': {'from': '2023-12-08T10:12:47.673+01:00',
#               'upto': '2024-12-31T23:30:00.000+01:00'},
#   'scope': {'lines': [{'designation': '502',
#                        'id': 502,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 50191,
#                             'name': 'Pyramidvägen',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 2},
#  {'created': '2024-12-16T10:22:16.46+01:00',
#   'deviation_case_id': 4355890,
#   'message_variants': [{'details': 'Buss linje 840 mot Handens station stannar '
#                                    'inte vid Älta centrum från och med  '
#                                    '2024-10-14 på grund av vägarbete. '
#                                    'Resenärer hänvisas till ett tillfälligt '
#                                    'hållplatsläge på Ältavägen.\n'
#                                    'Detta beräknas pågå till och med  '
#                                    '2025-01-24.',
#                         'header': 'Indragen hållplats',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 840'}],
#   'priority': {'importance_level': 7, 'influence_level': 3, 'urgency_level': 1},
#   'publish': {'from': '2024-12-16T10:22:16.460+01:00',
#               'upto': '2025-01-24T23:30:00.000+01:00'},
#   'scope': {'lines': [{'designation': '840',
#                        'id': 840,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 40049,
#                             'name': 'Älta centrum',
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 2},
#  {'created': '2024-12-03T13:41:44.617+01:00',
#   'deviation_case_id': 4957404,
#   'message_variants': [{'details': 'Fr.o.m. 15 december börjar linje 624 '
#                                    'trafikera hållplatsläge P i Danderyds '
#                                    'sjukhus',
#                         'header': 'Ändrat hållplatsläge',
#                         'language': 'sv',
#                         'scope_alias': 'Buss 624'}],
#   'priority': {'importance_level': 5, 'influence_level': 5, 'urgency_level': 1},
#   'publish': {'from': '2024-12-03T13:41:44.610+01:00',
#               'upto': '2024-12-31T13:06:00.000+01:00'},
#   'scope': {'lines': [{'designation': '624',
#                        'id': 624,
#                        'transport_authority': 1,
#                        'transport_mode': 'BUS'}],
#             'stop_areas': [{'id': 50366,
#                             'name': 'Danderyds sjukhus',
#                             'stop_points': [{'id': 60006,
#                                              'name': 'Danderyds sjukhus'}],
#                             'transport_authority': 1,
#                             'type': 'BUSTERM'}]},
#   'version': 1}]

# %% [markdown]
# ## Extract data from stop points API
# Preview of the data fetched from the stop points API

# %%
stop_points_url = 'https://transport.integration.sl.se/v1/stop-points'

stop_points = requests.get(stop_points_url).json()

stop_points
# Out:
# [{'id': 101,
#   'gid': 9022001000101001,
#   'pattern_point_gid': 9025001000000101,
#   'name': 'Stavsnäs',
#   'sname': 'Stavsnäs',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.2864051510743,
#   'lon': 18.704700202055,
#   'door_orientation': 305.1,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 101, 'name': 'Stavsnäs', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 102,
#   'gid': 9022001000102001,
#   'pattern_point_gid': 9025001000000102,
#   'name': 'Styrsvik',
#   'sname': 'Styrsvik',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.2801846162324,
#   'lon': 18.73142684354,
#   'door_orientation': 20.8,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 102, 'name': 'Styrsvik', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 103,
#   'gid': 9022001000103001,
#   'pattern_point_gid': 9025001000000103,
#   'name': 'Nämdöböte',
#   'sname': 'Nämdöböte',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.2087311910124,
#   'lon': 18.7400604266611,
#   'door_orientation': 39.8,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 103, 'name': 'Nämdöböte', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 104,
#   'gid': 9022001000104001,
#   'pattern_point_gid': 9025001000000104,
#   'name': 'Aspö',
#   'sname': 'Aspö',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.2158433258859,
#   'lon': 18.7534108327426,
#   'door_orientation': 158.4,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 104, 'name': 'Aspö', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 105,
#   'gid': 9022001000105001,
#   'pattern_point_gid': 9025001000000105,
#   'name': 'Idöborg',
#   'sname': 'Idöborg',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.2043095379509,
#   'lon': 18.757769806169,
#   'door_orientation': 109.2,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 105, 'name': 'Idöborg', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 106,
#   'gid': 9022001000106001,
#   'pattern_point_gid': 9025001000000106,
#   'name': 'Östanvik',
#   'sname': 'Östanvik',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.1974561678577,
#   'lon': 18.7398251205664,
#   'door_orientation': 232.5,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 106, 'name': 'Östanvik', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 107,
#   'gid': 9022001000107001,
#   'pattern_point_gid': 9025001000000107,
#   'name': 'Kalkberget',
#   'sname': 'Kalkberget',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.1916281875394,
#   'lon': 18.7195816731566,
#   'door_orientation': 164.1,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 107, 'name': 'Kalkberget', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 108,
#   'gid': 9022001000108001,
#   'pattern_point_gid': 9025001000000108,
#   'name': 'Västanvik',
#   'sname': 'Västanvik',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.187559318038,
#   'lon': 18.7068934920537,
#   'door_orientation': 208.3,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 108, 'name': 'Västanvik', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 109,
#   'gid': 9022001000109001,
#   'pattern_point_gid': 9025001000000109,
#   'name': 'Solvik',
#   'sname': 'Solvik',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.1847584336211,
#   'lon': 18.7004588557391,
#   'door_orientation': 161.4,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 109, 'name': 'Solvik', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 110,
#   'gid': 9022001000110001,
#   'pattern_point_gid': 9025001000000110,
#   'name': 'Orrön',
#   'sname': 'Orrön',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.1805106110916,
#   'lon': 18.7006296846519,
#   'door_orientation': 29.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 110, 'name': 'Orrön', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 111,
#   'gid': 9022001000111001,
#   'pattern_point_gid': 9025001000000111,
#   'name': 'Sand',
#   'sname': 'Sand',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.1823549356111,
#   'lon': 18.6926845014143,
#   'door_orientation': 255.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 111, 'name': 'Sand', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 112,
#   'gid': 9022001000112001,
#   'pattern_point_gid': 9025001000000112,
#   'name': 'Bunkvik',
#   'sname': 'Bunkvik',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.1775374666525,
#   'lon': 18.6698351431411,
#   'door_orientation': 196.4,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 112, 'name': 'Bunkvik', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 113,
#   'gid': 9022001000113001,
#   'pattern_point_gid': 9025001000000113,
#   'name': 'Ängsholmen',
#   'sname': 'Ängsholmen',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.1727233704907,
#   'lon': 18.6559931996021,
#   'door_orientation': 180.2,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 113, 'name': 'Ängsholmen', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 114,
#   'gid': 9022001000114001,
#   'pattern_point_gid': 9025001000000114,
#   'name': 'Uvö',
#   'sname': 'Uvö',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.1750397349831,
#   'lon': 18.6487458628128,
#   'door_orientation': 205.5,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 114, 'name': 'Uvö', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 115,
#   'gid': 9022001000115001,
#   'pattern_point_gid': 9025001000000115,
#   'name': 'Sunnansund',
#   'sname': 'Sunnansund',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.1710290638712,
#   'lon': 18.6391956764284,
#   'door_orientation': 161.8,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 115, 'name': 'Sunnansund', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 116,
#   'gid': 9022001000116001,
#   'pattern_point_gid': 9025001000000116,
#   'name': 'Mörtö',
#   'sname': 'Mörtö',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.1624531889308,
#   'lon': 18.6289360101197,
#   'door_orientation': 336.6,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 116, 'name': 'Mörtö', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 117,
#   'gid': 9022001000117001,
#   'pattern_point_gid': 9025001000000117,
#   'name': 'Mörtö södra',
#   'sname': 'Mörtö södra',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.152702854963,
#   'lon': 18.6162825112961,
#   'door_orientation': 168.4,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 117, 'name': 'Mörtö södra', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 118,
#   'gid': 9022001000118001,
#   'pattern_point_gid': 9025001000000118,
#   'name': 'Gatan',
#   'sname': 'Gatan',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.2942987304674,
#   'lon': 18.7566985295224,
#   'door_orientation': 41.7,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 118, 'name': 'Gatan', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 119,
#   'gid': 9022001000119001,
#   'pattern_point_gid': 9025001000000119,
#   'name': 'Långvik',
#   'sname': 'Långvik',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.2962350396711,
#   'lon': 18.7717982321116,
#   'door_orientation': 351.7,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 119, 'name': 'Långvik', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 120,
#   'gid': 9022001000120001,
#   'pattern_point_gid': 9025001000000120,
#   'name': 'Västra Skarprunmarn',
#   'sname': 'V. Skarprunmarn',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3054457791065,
#   'lon': 18.8141674466936,
#   'door_orientation': 53.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 120, 'name': 'Västra Skarprunmarn', 'type': 'SHIPBER'},
#   'valid': {'from': '2022-12-16T00:00:00'}},
#  {'id': 121,
#   'gid': 9022001000121001,
#   'pattern_point_gid': 9025001000000121,
#   'name': 'Hasselkobben',
#   'sname': 'Hasselkobben',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3146342226926,
#   'lon': 18.8328005246787,
#   'door_orientation': 242.1,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 121, 'name': 'Hasselkobben', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 122,
#   'gid': 9022001000122001,
#   'pattern_point_gid': 9025001000000122,
#   'name': 'Hasselö',
#   'sname': 'Hasselö',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3167328585584,
#   'lon': 18.8448550414639,
#   'door_orientation': 202.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 122, 'name': 'Hasselö', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 123,
#   'gid': 9022001000123001,
#   'pattern_point_gid': 9025001000000123,
#   'name': 'Mjölkkilen',
#   'sname': 'Mjölkkilen',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3024978417472,
#   'lon': 18.8428596102376,
#   'door_orientation': 337.3,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 123, 'name': 'Mjölkkilen', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 124,
#   'gid': 9022001000124001,
#   'pattern_point_gid': 9025001000000124,
#   'name': 'Idholmen',
#   'sname': 'Idholmen',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.2989572419644,
#   'lon': 18.8567851883754,
#   'door_orientation': 343.9,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 124, 'name': 'Idholmen', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 125,
#   'gid': 9022001000125001,
#   'pattern_point_gid': 9025001000000125,
#   'name': 'Sandhamn',
#   'sname': 'Sandhamn',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.288430888628,
#   'lon': 18.9154256380379,
#   'door_orientation': 298.3,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 125, 'name': 'Sandhamn', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 126,
#   'gid': 9022001000126001,
#   'pattern_point_gid': 9025001000000126,
#   'name': 'Harö',
#   'sname': 'Harö',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3390064720446,
#   'lon': 18.9002754590088,
#   'door_orientation': 310.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 126, 'name': 'Harö', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 127,
#   'gid': 9022001000127001,
#   'pattern_point_gid': 9025001000000127,
#   'name': 'Hagede',
#   'sname': 'Hagede',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3462633922717,
#   'lon': 18.8993133547759,
#   'door_orientation': 211.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 127, 'name': 'Hagede', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 128,
#   'gid': 9022001000128001,
#   'pattern_point_gid': 9025001000000128,
#   'name': 'Koviksudde',
#   'sname': 'Koviksudde',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3631905042234,
#   'lon': 18.3421237475835,
#   'door_orientation': 342.5,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 128, 'name': 'Koviksudde', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 129,
#   'gid': 9022001000129001,
#   'pattern_point_gid': 9025001000000129,
#   'name': 'Norra Lagnö',
#   'sname': 'Norra Lagnö',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3552975910006,
#   'lon': 18.4115436852053,
#   'door_orientation': 331.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 129, 'name': 'Norra Lagnö', 'type': 'SHIPBER'},
#   'valid': {'from': '2024-06-05T00:00:00'}},
#  {'id': 130,
#   'gid': 9022001000130001,
#   'pattern_point_gid': 9025001000000130,
#   'name': 'Bjurön',
#   'sname': 'Bjurön',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4389342654427,
#   'lon': 18.4397501373919,
#   'door_orientation': 7.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 130, 'name': 'Bjurön', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-07-03T00:00:00'}},
#  {'id': 131,
#   'gid': 9022001000131001,
#   'pattern_point_gid': 9025001000000131,
#   'name': 'Losten',
#   'sname': 'Losten',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4540079790131,
#   'lon': 18.4455019671647,
#   'door_orientation': 125.5,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 131, 'name': 'Losten', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 132,
#   'gid': 9022001000132001,
#   'pattern_point_gid': 9025001000000132,
#   'name': 'Storkrån',
#   'sname': 'Storkrån',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.454815757826,
#   'lon': 18.4550646534732,
#   'door_orientation': 28.5,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 132, 'name': 'Storkrån', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 133,
#   'gid': 9022001000133001,
#   'pattern_point_gid': 9025001000000133,
#   'name': 'Lilla Saxaren',
#   'sname': 'Lilla Saxaren',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4520382406173,
#   'lon': 18.4723458034339,
#   'door_orientation': 104.4,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 133, 'name': 'Lilla Saxaren', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 134,
#   'gid': 9022001000134001,
#   'pattern_point_gid': 9025001000000134,
#   'name': 'Stora Saxaren',
#   'sname': 'Stora Saxaren',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4502957718955,
#   'lon': 18.483093740504,
#   'door_orientation': 94.9,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 134, 'name': 'Stora Saxaren', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 135,
#   'gid': 9022001000135001,
#   'pattern_point_gid': 9025001000000135,
#   'name': 'Bernhardsro',
#   'sname': 'Bernhardsro',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4274554804105,
#   'lon': 18.4192860791686,
#   'door_orientation': 157.8,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 135, 'name': 'Bernhardsro', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 136,
#   'gid': 9022001000136001,
#   'pattern_point_gid': 9025001000000136,
#   'name': 'Björknäs',
#   'sname': 'Björknäs',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4273811662951,
#   'lon': 18.424517606512,
#   'door_orientation': 169.7,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 136, 'name': 'Björknäs', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 137,
#   'gid': 9022001000137001,
#   'pattern_point_gid': 9025001000000137,
#   'name': 'Skäggaudd',
#   'sname': 'Skäggaudd',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4237801319887,
#   'lon': 18.4244004512801,
#   'door_orientation': 34.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 137, 'name': 'Skäggaudd', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 138,
#   'gid': 9022001000138001,
#   'pattern_point_gid': 9025001000000138,
#   'name': 'Lilla Betsö',
#   'sname': 'Lilla Betsö',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4286747428841,
#   'lon': 18.4334334217086,
#   'door_orientation': 168.9,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 138, 'name': 'Lilla Betsö', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 139,
#   'gid': 9022001000139001,
#   'pattern_point_gid': 9025001000000139,
#   'name': 'Stora Isskär',
#   'sname': 'Stora Isskär',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4273946666222,
#   'lon': 18.4400597523479,
#   'door_orientation': 193.3,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 139, 'name': 'Stora Isskär', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 141,
#   'gid': 9022001000141001,
#   'pattern_point_gid': 9025001000000141,
#   'name': 'Halleberg',
#   'sname': 'Halleberg',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4261585690967,
#   'lon': 18.4602901133812,
#   'door_orientation': 6.4,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 141, 'name': 'Halleberg', 'type': 'SHIPBER'},
#   'valid': {'from': '2023-08-31T00:00:00'}},
#  {'id': 142,
#   'gid': 9022001000142001,
#   'pattern_point_gid': 9025001000000142,
#   'name': 'Skärmaräng',
#   'sname': 'Skärmaräng',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4203517451137,
#   'lon': 18.4677568407949,
#   'door_orientation': 34.7,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 142, 'name': 'Skärmaräng', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 143,
#   'gid': 9022001000143001,
#   'pattern_point_gid': 9025001000000143,
#   'name': 'Vårholma',
#   'sname': 'Vårholma',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.424485232069,
#   'lon': 18.4718489076552,
#   'door_orientation': 169.5,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 143, 'name': 'Vårholma', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 144,
#   'gid': 9022001000144001,
#   'pattern_point_gid': 9025001000000144,
#   'name': 'Vårlunda',
#   'sname': 'Vårlunda',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4235477520668,
#   'lon': 18.4830766215506,
#   'door_orientation': 182.7,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 144, 'name': 'Vårlunda', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 145,
#   'gid': 9022001000145001,
#   'pattern_point_gid': 9025001000000145,
#   'name': 'Sippsö',
#   'sname': 'Sippsö',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4221540543119,
#   'lon': 18.4938510458296,
#   'door_orientation': 187.4,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 145, 'name': 'Sippsö', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 146,
#   'gid': 9022001000146001,
#   'pattern_point_gid': 9025001000000146,
#   'name': 'Lillsved',
#   'sname': 'Lillsved',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4131388922905,
#   'lon': 18.4962011769293,
#   'door_orientation': 36.3,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 146, 'name': 'Lillsved', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 147,
#   'gid': 9022001000147001,
#   'pattern_point_gid': 9025001000000147,
#   'name': 'Södra Grinda',
#   'sname': 'Södra Grinda',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4073689399977,
#   'lon': 18.553045568542,
#   'door_orientation': 150.5,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 147, 'name': 'Södra Grinda', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 148,
#   'gid': 9022001000148001,
#   'pattern_point_gid': 9025001000000148,
#   'name': 'Norra Grinda',
#   'sname': 'Norra Grinda',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4190600914302,
#   'lon': 18.5587514908739,
#   'door_orientation': 327.8,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 148, 'name': 'Norra Grinda', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 149,
#   'gid': 9022001000149001,
#   'pattern_point_gid': 9025001000000149,
#   'name': 'Viggsö',
#   'sname': 'Viggsö',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4086361263371,
#   'lon': 18.5351946268916,
#   'door_orientation': 317.4,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 149, 'name': 'Viggsö', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 150,
#   'gid': 9022001000150001,
#   'pattern_point_gid': 9025001000000150,
#   'name': 'Norra Svartsö',
#   'sname': 'Norra Svartsö',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4588246275233,
#   'lon': 18.6767940122859,
#   'door_orientation': 52.7,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 150, 'name': 'Norra Svartsö', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 151,
#   'gid': 9022001000151001,
#   'pattern_point_gid': 9025001000000151,
#   'name': 'Karklö',
#   'sname': 'Karklö',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4165262290474,
#   'lon': 18.6291693811349,
#   'door_orientation': 56.3,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 151, 'name': 'Karklö', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 152,
#   'gid': 9022001000152001,
#   'pattern_point_gid': 9025001000000152,
#   'name': 'Trångholmen',
#   'sname': 'Trångholmen',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4288119239171,
#   'lon': 18.6469642847638,
#   'door_orientation': 46.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 152, 'name': 'Trångholmen', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 153,
#   'gid': 9022001000153001,
#   'pattern_point_gid': 9025001000000153,
#   'name': 'Alsvik',
#   'sname': 'Alsvik',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4378407327919,
#   'lon': 18.657096095814,
#   'door_orientation': 158.8,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 153, 'name': 'Alsvik', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 154,
#   'gid': 9022001000154001,
#   'pattern_point_gid': 9025001000000154,
#   'name': 'Hjälmö',
#   'sname': 'Hjälmö',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4196229505645,
#   'lon': 18.6777761658444,
#   'door_orientation': 22.2,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 154, 'name': 'Hjälmö', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 155,
#   'gid': 9022001000155001,
#   'pattern_point_gid': 9025001000000155,
#   'name': 'Trädgårdarna',
#   'sname': 'Trädgårdarna',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4314981373474,
#   'lon': 18.6758372312539,
#   'door_orientation': 201.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 155, 'name': 'Trädgårdarna', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 156,
#   'gid': 9022001000156001,
#   'pattern_point_gid': 9025001000000156,
#   'name': 'Skälvik',
#   'sname': 'Skälvik',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4439833928996,
#   'lon': 18.6806353564985,
#   'door_orientation': 216.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 156, 'name': 'Skälvik', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 157,
#   'gid': 9022001000157001,
#   'pattern_point_gid': 9025001000000157,
#   'name': 'Karlshem',
#   'sname': 'Karlshem',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4342681638175,
#   'lon': 18.6894782751794,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 157, 'name': 'Karlshem', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 158,
#   'gid': 9022001000158001,
#   'pattern_point_gid': 9025001000000158,
#   'name': 'Lådna',
#   'sname': 'Lådna',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4338261204629,
#   'lon': 18.7025376879476,
#   'door_orientation': 169.9,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 158, 'name': 'Lådna', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-07-03T00:00:00'}},
#  {'id': 159,
#   'gid': 9022001000159001,
#   'pattern_point_gid': 9025001000000159,
#   'name': 'Träskökvarn',
#   'sname': 'Träskökvarn',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4420558573149,
#   'lon': 18.6998406733899,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 159, 'name': 'Träskökvarn', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 160,
#   'gid': 9022001000160001,
#   'pattern_point_gid': 9025001000000160,
#   'name': 'Gistholmen',
#   'sname': 'Gistholmen',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4519987283372,
#   'lon': 18.7458083899562,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 160, 'name': 'Gistholmen', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 161,
#   'gid': 9022001000161001,
#   'pattern_point_gid': 9025001000000161,
#   'name': 'Söderboudd',
#   'sname': 'Söderboudd',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4554890453202,
#   'lon': 18.7397676278024,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 161, 'name': 'Söderboudd', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 162,
#   'gid': 9022001000162001,
#   'pattern_point_gid': 9025001000000162,
#   'name': 'Hägerö',
#   'sname': 'Hägerö',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3977538204375,
#   'lon': 18.6173417699775,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 162, 'name': 'Hägerö', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 163,
#   'gid': 9022001000163001,
#   'pattern_point_gid': 9025001000000163,
#   'name': 'Gällnö',
#   'sname': 'Gällnö',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3902709081194,
#   'lon': 18.639452662887,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 163, 'name': 'Gällnö', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 164,
#   'gid': 9022001000164001,
#   'pattern_point_gid': 9025001000000164,
#   'name': 'Galtholmen',
#   'sname': 'Galtholmen',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3848204977002,
#   'lon': 18.690388443085,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 164, 'name': 'Galtholmen', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 165,
#   'gid': 9022001000165001,
#   'pattern_point_gid': 9025001000000165,
#   'name': 'Gällnönäs',
#   'sname': 'Gällnönäs',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.396564887912,
#   'lon': 18.7057502675953,
#   'door_orientation': 213.3,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 165, 'name': 'Gällnönäs', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 166,
#   'gid': 9022001000166001,
#   'pattern_point_gid': 9025001000000166,
#   'name': 'Puttisholmen',
#   'sname': 'Puttisholmen',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3767572179372,
#   'lon': 18.6324893818756,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 166, 'name': 'Puttisholmen', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 167,
#   'gid': 9022001000167001,
#   'pattern_point_gid': 9025001000000167,
#   'name': 'Ängsholmen',
#   'sname': 'Ängsholmen',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3798292281548,
#   'lon': 18.6502592318409,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 167, 'name': 'Ängsholmen', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 168,
#   'gid': 9022001000168001,
#   'pattern_point_gid': 9025001000000168,
#   'name': 'Sollenkroka',
#   'sname': 'Sollenkroka',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3730152261864,
#   'lon': 18.6987217675588,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 168, 'name': 'Sollenkroka', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 169,
#   'gid': 9022001000169001,
#   'pattern_point_gid': 9025001000000169,
#   'name': 'Sollenkrokaö',
#   'sname': 'Sollenkrokaö',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3779200075823,
#   'lon': 18.707377777815,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 169, 'name': 'Sollenkrokaö', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 170,
#   'gid': 9022001000170001,
#   'pattern_point_gid': 9025001000000170,
#   'name': 'Arbodaö',
#   'sname': 'Arbodaö',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3774961414259,
#   'lon': 18.7294755501426,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 170, 'name': 'Arbodaö', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 171,
#   'gid': 9022001000171001,
#   'pattern_point_gid': 9025001000000171,
#   'name': 'Ytterö',
#   'sname': 'Ytterö',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3825261877043,
#   'lon': 18.7720864605616,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 171, 'name': 'Ytterö', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 172,
#   'gid': 9022001000172001,
#   'pattern_point_gid': 9025001000000172,
#   'name': 'Träskö-Gåln',
#   'sname': 'Träskö-Gåln',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3845725116203,
#   'lon': 18.7734417830239,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 172, 'name': 'Träskö-Gåln', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 173,
#   'gid': 9022001000173001,
#   'pattern_point_gid': 9025001000000173,
#   'name': 'Norra Stavsudda',
#   'sname': 'Norra Stavsudda',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.404277559222,
#   'lon': 18.7799552947909,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 173, 'name': 'Norra Stavsudda', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 174,
#   'gid': 9022001000174001,
#   'pattern_point_gid': 9025001000000174,
#   'name': 'Södra Träskö',
#   'sname': 'Södra Träskö',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3828382019567,
#   'lon': 18.7907631298652,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 174, 'name': 'Södra Träskö', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 175,
#   'gid': 9022001000175001,
#   'pattern_point_gid': 9025001000000175,
#   'name': 'Södra Stavsudda',
#   'sname': 'Södra Stavsudda',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3882968314942,
#   'lon': 18.8104238315165,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 175, 'name': 'Södra Stavsudda', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 176,
#   'gid': 9022001000176001,
#   'pattern_point_gid': 9025001000000176,
#   'name': 'Korsö',
#   'sname': 'Korsö',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3814487135215,
#   'lon': 18.8140417663207,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 176, 'name': 'Korsö', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 177,
#   'gid': 9022001000177001,
#   'pattern_point_gid': 9025001000000177,
#   'name': 'Granholmen',
#   'sname': 'Granholmen',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3728971071946,
#   'lon': 18.8774650084891,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 177, 'name': 'Granholmen', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 178,
#   'gid': 9022001000178001,
#   'pattern_point_gid': 9025001000000178,
#   'name': 'Södermöja',
#   'sname': 'Södermöja',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4036735496988,
#   'lon': 18.8743211771314,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 178, 'name': 'Södermöja', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 179,
#   'gid': 9022001000179001,
#   'pattern_point_gid': 9025001000000179,
#   'name': 'Möjaström',
#   'sname': 'Möjaström',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4040288778351,
#   'lon': 18.8747673375993,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 179, 'name': 'Möjaström', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 180,
#   'gid': 9022001000180001,
#   'pattern_point_gid': 9025001000000180,
#   'name': 'Berg',
#   'sname': 'Berg',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4060576330508,
#   'lon': 18.8884533801681,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 180, 'name': 'Berg', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 181,
#   'gid': 9022001000181001,
#   'pattern_point_gid': 9025001000000181,
#   'name': 'Löka',
#   'sname': 'Löka',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4103748438408,
#   'lon': 18.8959148983406,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 181, 'name': 'Löka', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 182,
#   'gid': 9022001000182001,
#   'pattern_point_gid': 9025001000000182,
#   'name': 'Ramsmora',
#   'sname': 'Ramsmora',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4238738098065,
#   'lon': 18.9095708364207,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 182, 'name': 'Ramsmora', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 183,
#   'gid': 9022001000183001,
#   'pattern_point_gid': 9025001000000183,
#   'name': 'Långvik',
#   'sname': 'Långvik',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4423727673719,
#   'lon': 18.9207462516946,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 183, 'name': 'Långvik', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 184,
#   'gid': 9022001000184001,
#   'pattern_point_gid': 9025001000000184,
#   'name': 'Dragedet',
#   'sname': 'Dragedet',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4431837774851,
#   'lon': 18.8864351755124,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 184, 'name': 'Dragedet', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 185,
#   'gid': 9022001000185001,
#   'pattern_point_gid': 9025001000000185,
#   'name': 'Stora Kalholmen',
#   'sname': 'Stora Kalholmen',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.455165897931,
#   'lon': 18.8225818500194,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 185, 'name': 'Stora Kalholmen', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 187,
#   'gid': 9022001000187001,
#   'pattern_point_gid': 9025001000000187,
#   'name': 'Boda brygga',
#   'sname': 'Boda brygga',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3699862950806,
#   'lon': 18.605065222154,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 187, 'name': 'Boda brygga', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 188,
#   'gid': 9022001000188001,
#   'pattern_point_gid': 9025001000000188,
#   'name': 'Karsholm',
#   'sname': 'Karsholm',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3944145910594,
#   'lon': 18.7809354229809,
#   'door_orientation': 5.6,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 188, 'name': 'Karsholm', 'type': 'SHIPBER'},
#   'valid': {'from': '2016-12-01T00:00:00'}},
#  {'id': 193,
#   'gid': 9022001000193001,
#   'pattern_point_gid': 9025001000000193,
#   'name': 'Söderholm',
#   'sname': 'Söderholm',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3869845316328,
#   'lon': 18.8070338470177,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 193, 'name': 'Söderholm', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 195,
#   'gid': 9022001000195001,
#   'pattern_point_gid': 9025001000000195,
#   'name': 'Korsö',
#   'sname': 'Korsö',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.2870011630362,
#   'lon': 18.9469607859339,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 195, 'name': 'Korsö', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 201,
#   'gid': 9022001000201001,
#   'pattern_point_gid': 9025001000000201,
#   'name': 'Årsta brygga',
#   'sname': 'Årsta brygga',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.0820549109784,
#   'lon': 18.1734644675615,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 201, 'name': 'Årsta brygga', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 202,
#   'gid': 9022001000202001,
#   'pattern_point_gid': 9025001000000202,
#   'name': 'Gruvbryggan',
#   'sname': 'Gruvbryggan',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 58.9704181911603,
#   'lon': 18.3251135637057,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 202, 'name': 'Gruvbryggan', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 203,
#   'gid': 9022001000203001,
#   'pattern_point_gid': 9025001000000203,
#   'name': 'Näsudden',
#   'sname': 'Näsudden',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 58.9617061018194,
#   'lon': 18.2932670370204,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 203, 'name': 'Näsudden', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 204,
#   'gid': 9022001000204001,
#   'pattern_point_gid': 9025001000000204,
#   'name': 'Spränga',
#   'sname': 'Spränga',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 58.957605661872,
#   'lon': 18.2944067157702,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 204, 'name': 'Spränga', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 206,
#   'gid': 9022001000206001,
#   'pattern_point_gid': 9025001000000206,
#   'name': 'Ängsö',
#   'sname': 'Ängsö',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.1949822487778,
#   'lon': 18.4424825507151,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 206, 'name': 'Ängsö', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 207,
#   'gid': 9022001000207001,
#   'pattern_point_gid': 9025001000000207,
#   'name': 'Gränö',
#   'sname': 'Gränö',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.1913786107469,
#   'lon': 18.4546450733047,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 207, 'name': 'Gränö', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 208,
#   'gid': 9022001000208001,
#   'pattern_point_gid': 9025001000000208,
#   'name': 'Kalvholmen',
#   'sname': 'Kalvholmen',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.1888800704293,
#   'lon': 18.4522730691408,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 208, 'name': 'Kalvholmen', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 209,
#   'gid': 9022001000209001,
#   'pattern_point_gid': 9025001000000209,
#   'name': 'Dalarö',
#   'sname': 'Dalarö',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.129570538223,
#   'lon': 18.4052213317644,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 209, 'name': 'Dalarö', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 210,
#   'gid': 9022001000210001,
#   'pattern_point_gid': 9025001000000210,
#   'name': 'Jutholmen',
#   'sname': 'Jutholmen',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.125238073549,
#   'lon': 18.409336718729,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 210, 'name': 'Jutholmen', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 211,
#   'gid': 9022001000211001,
#   'pattern_point_gid': 9025001000000211,
#   'name': 'Aspö',
#   'sname': 'Aspö',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.1171345487338,
#   'lon': 18.4115898838419,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 211, 'name': 'Aspö', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 212,
#   'gid': 9022001000212001,
#   'pattern_point_gid': 9025001000000212,
#   'name': 'Segholmen',
#   'sname': 'Segholmen',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.1136490392866,
#   'lon': 18.4128860526626,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 212, 'name': 'Segholmen', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 213,
#   'gid': 9022001000213001,
#   'pattern_point_gid': 9025001000000213,
#   'name': 'Dalarö skans',
#   'sname': 'Dalarö skans',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.1132926318806,
#   'lon': 18.3915277599505,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 213, 'name': 'Dalarö skans', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-02-24T00:00:00'}},
#  {'id': 214,
#   'gid': 9022001000214001,
#   'pattern_point_gid': 9025001000000214,
#   'name': 'Fåglarö',
#   'sname': 'Fåglarö',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.1039242270324,
#   'lon': 18.3988487508596,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 214, 'name': 'Fåglarö', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-02-25T00:00:00'}},
#  {'id': 215,
#   'gid': 9022001000215001,
#   'pattern_point_gid': 9025001000000215,
#   'name': 'Hässelmara',
#   'sname': 'Hässelmara',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.0891440756267,
#   'lon': 18.415409511501,
#   'door_orientation': 315.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 215, 'name': 'Hässelmara', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 218,
#   'gid': 9022001000218001,
#   'pattern_point_gid': 9025001000000218,
#   'name': 'Lättinge',
#   'sname': 'Lättinge',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.0448514587471,
#   'lon': 18.3652567088306,
#   'door_orientation': 167.7,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 218, 'name': 'Lättinge', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 219,
#   'gid': 9022001000219001,
#   'pattern_point_gid': 9025001000000219,
#   'name': 'Björkösund',
#   'sname': 'Björkösund',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.0490897247044,
#   'lon': 18.3414583797686,
#   'door_orientation': 107.7,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 219, 'name': 'Björkösund', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 220,
#   'gid': 9022001000220001,
#   'pattern_point_gid': 9025001000000220,
#   'name': 'Nåttarö',
#   'sname': 'Nåttarö',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 58.8812211885495,
#   'lon': 18.110596097843,
#   'door_orientation': 38.3,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 220, 'name': 'Nåttarö', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 221,
#   'gid': 9022001000221001,
# ...
#   'sname': 'Granholmen',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3762533422272,
#   'lon': 18.3085023111377,
#   'door_orientation': 246.6,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 8033, 'name': 'Granholmen', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 8034,
#   'gid': 9022001008034001,
#   'pattern_point_gid': 9025001000008034,
#   'name': 'Riset',
#   'sname': 'Riset',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3599735664551,
#   'lon': 18.28556287855,
#   'door_orientation': 28.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 8034, 'name': 'Riset', 'type': 'SHIPBER'},
#   'valid': {'from': '2024-05-29T00:00:00'}},
#  {'id': 8035,
#   'gid': 9022001008035001,
#   'pattern_point_gid': 9025001000008035,
#   'name': 'Gåshaga brygga',
#   'sname': 'Gåshaga brygga',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3570774448389,
#   'lon': 18.2350117405149,
#   'door_orientation': 300.1,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 8035, 'name': 'Gåshaga brygga', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 8036,
#   'gid': 9022001008036001,
#   'pattern_point_gid': 9025001000008036,
#   'name': 'Hasseludden',
#   'sname': 'Hasseludden',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.348591858791,
#   'lon': 18.2444806134597,
#   'door_orientation': 15.4,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 8036, 'name': 'Hasseludden', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 8037,
#   'gid': 9022001008037001,
#   'pattern_point_gid': 9025001000008037,
#   'name': 'Klippudden',
#   'sname': 'Klippudden',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.345900099114,
#   'lon': 18.2236716250136,
#   'door_orientation': 222.9,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 8037, 'name': 'Klippudden', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 8038,
#   'gid': 9022001008038001,
#   'pattern_point_gid': 9025001000008038,
#   'name': 'Telegrafberget',
#   'sname': 'Telegrafberget',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3414066092173,
#   'lon': 18.2258492435901,
#   'door_orientation': 87.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 8038, 'name': 'Telegrafberget', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 8039,
#   'gid': 9022001008039001,
#   'pattern_point_gid': 9025001000008039,
#   'name': 'Nacka strand',
#   'sname': 'Nacka strand',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.31806874186,
#   'lon': 18.1568629298651,
#   'door_orientation': 331.5,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 8039, 'name': 'Nacka strand', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-04-17T00:00:00'}},
#  {'id': 8040,
#   'gid': 9022001008040001,
#   'pattern_point_gid': 9025001000008040,
#   'name': 'Strömkajen',
#   'sname': 'Strömkajen',
#   'designation': '1',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3288451146265,
#   'lon': 18.0760704080207,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 8040, 'name': 'Strömkajen', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-12-17T00:00:00'}},
#  {'id': 8041,
#   'gid': 9022001008041001,
#   'pattern_point_gid': 9025001000008041,
#   'name': 'Ropsten',
#   'sname': 'Ropsten',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3583213559771,
#   'lon': 18.1063379431711,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 8041, 'name': 'Ropsten', 'type': 'SHIPBER'},
#   'valid': {'from': '2023-12-10T00:00:00'}},
#  {'id': 8042,
#   'gid': 9022001008040002,
#   'pattern_point_gid': 9025001000008042,
#   'name': 'Strömkajen',
#   'sname': 'Strömkajen',
#   'designation': '2',
#   'local_num': 2,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3288451146265,
#   'lon': 18.0760704080207,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 8040, 'name': 'Strömkajen', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-12-17T00:00:00'}},
#  {'id': 8043,
#   'gid': 9022001008040003,
#   'pattern_point_gid': 9025001000008043,
#   'name': 'Strömkajen',
#   'sname': 'Strömkajen',
#   'designation': '3',
#   'local_num': 3,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3288451146265,
#   'lon': 18.0760704080207,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 8040, 'name': 'Strömkajen', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-12-17T00:00:00'}},
#  {'id': 8044,
#   'gid': 9022001008040004,
#   'pattern_point_gid': 9025001000008044,
#   'name': 'Strömkajen',
#   'sname': 'Strömkajen',
#   'designation': '4',
#   'local_num': 4,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3288451146265,
#   'lon': 18.0760704080207,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 8040, 'name': 'Strömkajen', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-12-17T00:00:00'}},
#  {'id': 8045,
#   'gid': 9022001008040005,
#   'pattern_point_gid': 9025001000008045,
#   'name': 'Strömkajen',
#   'sname': 'Strömkajen',
#   'designation': '5',
#   'local_num': 5,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3288451146265,
#   'lon': 18.0760704080207,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 8040, 'name': 'Strömkajen', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-12-17T00:00:00'}},
#  {'id': 8046,
#   'gid': 9022001008040006,
#   'pattern_point_gid': 9025001000008046,
#   'name': 'Strömkajen',
#   'sname': 'Strömkajen',
#   'designation': '6',
#   'local_num': 6,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3288451146265,
#   'lon': 18.0760704080207,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 8040, 'name': 'Strömkajen', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-12-17T00:00:00'}},
#  {'id': 8047,
#   'gid': 9022001008040007,
#   'pattern_point_gid': 9025001000008047,
#   'name': 'Strömkajen',
#   'sname': 'Strömkajen',
#   'designation': '7',
#   'local_num': 7,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3288451146265,
#   'lon': 18.0760704080207,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 8040, 'name': 'Strömkajen', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-12-17T00:00:00'}},
#  {'id': 8048,
#   'gid': 9022001008040008,
#   'pattern_point_gid': 9025001000008048,
#   'name': 'Strömkajen',
#   'sname': 'Strömkajen',
#   'designation': '8',
#   'local_num': 8,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3288451146265,
#   'lon': 18.0760704080207,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 8040, 'name': 'Strömkajen', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-12-17T00:00:00'}},
#  {'id': 8049,
#   'gid': 9022001008040009,
#   'pattern_point_gid': 9025001000008049,
#   'name': 'Strömkajen',
#   'sname': 'Strömkajen',
#   'designation': '9',
#   'local_num': 9,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3288451146265,
#   'lon': 18.0760704080207,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 8040, 'name': 'Strömkajen', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-12-17T00:00:00'}},
#  {'id': 8050,
#   'gid': 9022001008040010,
#   'pattern_point_gid': 9025001000008050,
#   'name': 'Strömkajen',
#   'sname': 'Strömkajen',
#   'designation': '10',
#   'local_num': 10,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3288451146265,
#   'lon': 18.0760704080207,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 8040, 'name': 'Strömkajen', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-12-17T00:00:00'}},
#  {'id': 8051,
#   'gid': 9022001008040011,
#   'pattern_point_gid': 9025001000008051,
#   'name': 'Strömkajen',
#   'sname': 'Strömkajen',
#   'designation': '11',
#   'local_num': 11,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3288451146265,
#   'lon': 18.0760704080207,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 8040, 'name': 'Strömkajen', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-12-17T00:00:00'}},
#  {'id': 8052,
#   'gid': 9022001008052001,
#   'pattern_point_gid': 9025001000008052,
#   'name': 'Norra Lagnö',
#   'sname': 'Norra Lagnö',
#   'designation': '1',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3553798337291,
#   'lon': 18.4116618883651,
#   'door_orientation': 57.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 8052, 'name': 'Norra Lagnö', 'type': 'SHIPBER'},
#   'valid': {'from': '2024-04-11T00:00:00'}},
#  {'id': 8053,
#   'gid': 9022001008009002,
#   'pattern_point_gid': 9025001000008053,
#   'name': 'Allmänna gränd',
#   'sname': 'Allmänna gr',
#   'local_num': 2,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.324074379277,
#   'lon': 18.0946113991361,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 8009, 'name': 'Allmänna gränd', 'type': 'SHIPBER'},
#   'valid': {'from': '2023-10-07T00:00:00'}},
#  {'id': 8054,
#   'gid': 9022001008054001,
#   'pattern_point_gid': 9025001000008054,
#   'name': 'Slussen',
#   'sname': 'Slussen',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3237797159708,
#   'lon': 18.0763151634949,
#   'door_orientation': 138.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 8054, 'name': 'Slussen', 'type': 'SHIPBER'},
#   'valid': {'from': '2024-06-13T00:00:00'}},
#  {'id': 8055,
#   'gid': 9022001008054002,
#   'pattern_point_gid': 9025001000008055,
#   'name': 'Slussen',
#   'sname': 'Slussen',
#   'local_num': 2,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3227733081355,
#   'lon': 18.0759432962211,
#   'door_orientation': 320.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 8054, 'name': 'Slussen', 'type': 'SHIPBER'},
#   'valid': {'from': '2023-12-05T00:00:00'}},
#  {'id': 8056,
#   'gid': 9022001008056001,
#   'pattern_point_gid': 9025001000008056,
#   'name': 'Koviksudde',
#   'sname': 'Koviksudde',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3632939270058,
#   'lon': 18.3422145019349,
#   'door_orientation': 247.9,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 8056, 'name': 'Koviksudde', 'type': 'SHIPBER'},
#   'valid': {'from': '2023-10-13T00:00:00'}},
#  {'id': 8057,
#   'gid': 9022001008057001,
#   'pattern_point_gid': 9025001000008057,
#   'name': 'Skeppsholmen',
#   'sname': 'Skeppsholmen',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3249951278538,
#   'lon': 18.089138663763,
#   'door_orientation': 295.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 8057, 'name': 'Skeppsholmen', 'type': 'SHIPBER'},
#   'valid': {'from': '2024-03-14T00:00:00'}},
#  {'id': 8058,
#   'gid': 9022001008058001,
#   'pattern_point_gid': 9025001000008058,
#   'name': 'Ålstäket',
#   'sname': 'Ålstäket',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.315653569265,
#   'lon': 18.4588359918082,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 8058, 'name': 'Ålstäket', 'type': 'SHIPBER'},
#   'valid': {'from': '2023-10-24T00:00:00'}},
#  {'id': 8059,
#   'gid': 9022001008059001,
#   'pattern_point_gid': 9025001000008059,
#   'name': 'Tranholmen',
#   'sname': 'Tranholmen',
#   'local_num': 1,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.3764459423859,
#   'lon': 18.0920236829074,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 8059, 'name': 'Tranholmen', 'type': 'SHIPBER'},
#   'valid': {'from': '2023-11-07T00:00:00'}},
#  {'id': 8060,
#   'gid': 9022001008026002,
#   'pattern_point_gid': 9025001000008060,
#   'name': 'Vaxholm',
#   'sname': 'Vaxholm',
#   'designation': '2',
#   'local_num': 2,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4018255904407,
#   'lon': 18.3555024809714,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 8026, 'name': 'Vaxholm', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-12-17T00:00:00'}},
#  {'id': 8061,
#   'gid': 9022001008026003,
#   'pattern_point_gid': 9025001000008061,
#   'name': 'Vaxholm',
#   'sname': 'Vaxholm',
#   'designation': '3',
#   'local_num': 3,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4018255904407,
#   'lon': 18.3555024809714,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 8026, 'name': 'Vaxholm', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-12-17T00:00:00'}},
#  {'id': 8062,
#   'gid': 9022001008026004,
#   'pattern_point_gid': 9025001000008062,
#   'name': 'Vaxholm',
#   'sname': 'Vaxholm',
#   'designation': '4',
#   'local_num': 4,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4018255904407,
#   'lon': 18.3555024809714,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 8026, 'name': 'Vaxholm', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-12-17T00:00:00'}},
#  {'id': 8063,
#   'gid': 9022001008026005,
#   'pattern_point_gid': 9025001000008063,
#   'name': 'Vaxholm',
#   'sname': 'Vaxholm',
#   'designation': '5',
#   'local_num': 5,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4018255904407,
#   'lon': 18.3555024809714,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 8026, 'name': 'Vaxholm', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-12-17T00:00:00'}},
#  {'id': 8064,
#   'gid': 9022001008026006,
#   'pattern_point_gid': 9025001000008064,
#   'name': 'Vaxholm',
#   'sname': 'Vaxholm',
#   'designation': '6',
#   'local_num': 6,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4018255904407,
#   'lon': 18.3555024809714,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 8026, 'name': 'Vaxholm', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-12-17T00:00:00'}},
#  {'id': 8065,
#   'gid': 9022001008026007,
#   'pattern_point_gid': 9025001000008065,
#   'name': 'Vaxholm',
#   'sname': 'Vaxholm',
#   'designation': '7',
#   'local_num': 7,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4018255904407,
#   'lon': 18.3555024809714,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 8026, 'name': 'Vaxholm', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-12-17T00:00:00'}},
#  {'id': 8066,
#   'gid': 9022001008026008,
#   'pattern_point_gid': 9025001000008066,
#   'name': 'Vaxholm',
#   'sname': 'Vaxholm',
#   'designation': '8',
#   'local_num': 8,
#   'type': 'PIER',
#   'has_entrance': False,
#   'lat': 59.4018255904407,
#   'lon': 18.3555024809714,
#   'door_orientation': 0.0,
#   'transport_authority': {'id': 1, 'name': 'Storstockholms Lokaltrafik'},
#   'stop_area': {'id': 8026, 'name': 'Vaxholm', 'type': 'SHIPBER'},
#   'valid': {'from': '2021-12-17T00:00:00'}},
#  ...]
